# %% [markdown]
# # Introduction to Python for Text and Data Mining

# %% [markdown]
# In this notebook:
#
# - [Introduction to Python](#Introduction-to-Python)
# - [Working with Data](#Working-with-Data)
# - [Preliminary Text Analysis](#Preliminary-Text-Analysis)
# - [Processing Text for Analysis](#Processing-Text-for-Analysis)
# - [Advanced Text Mining Examples](#Advanced-Text-Mining-Examples)

# %% [markdown]
# # Introduction to Python

# %% [markdown]
# Python is a general use programming language popular amongst beginners and experts alike for its easy of use, readability, and flexibility. From it's origins as a language designed for teaching to being the primary language for machine learning applications, Python is capable of doing just about anything you need it to.
#
# No language is perfect and Python is no exception. Python is rarely the fastest option or necessarily the cleanest option depending on your application. It also requires a good working knowledge of the assorted packages and libraries that make life so much easier as a programmer.
#
# This notebook is designed to take you from no knowledge of python to a basic understanding of how to work with text data sets. It also demonstrates next steps and concepts to explore should you want to take your analysis further.

# %% [markdown]
# ## Jupyter and Navigating the Notebook

# %% [markdown]
# This interface is called a Jupyter Notebook. It allows us to run python interactively while including text content. Python can also be run as a 'script' - a single set of instructions read in order (i.e. not interactively) - which is popular for finished code.

# %% [markdown]
# To operate this notebook, you will need to execute boxes of code, called cells. To do this you can either click the *Run* button on the toolbar or use [Shift]+[Enter].
#
# Throughout this notebook you will see cells that are not code (like this one). These cells contain text in a language called Markdown. You can execute these cells to render formatted text. A cheatsheet for Markdown can be found [here](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet). There will also be comments with in the code itself that give additional information about the operation of the code, describe functions or show you places where you might want to make changes. These comments are always preceded by an octothorp (#) and in most cases be a different color from the surrounding text.
#
# Notebooks save automatically, however if you have made big changes your code, you can checkpoint it. This allows you to roll back changes to this point (or any previous checkpoints) should something break in the future.
#
# There are a few useful [keyboard shortcuts](https://gist.github.com/kidpixo/f4318f8c8143adee5b40) for modifying the cells in a notebook. To use these, click on the far left side of the cell such that the outline changes color (to blue in most cases), press [Enter]] to return to editing the cell's contents.
#
# -Add a cell **a**bove the current cell   [A]
#
# -Add a cell **b**elow the current cell   [B]
#
# -**D**elete the current cell   [D,D]
#
# **Let's try it out!**

# %% [markdown]
# ### Basic Math

# %% [markdown]
# Python can do simple mathematical operations just like a calculator.

# %%
1+1
# Out:
# 2

# %%
2.5-2.0
# Out:
# 0.5

# %% [markdown]
# ## Variables and Objects

# %% [markdown]
# Calculations are nice but we really want to be able to store our calculations in memory so that we can access them later. We do that by assigning variables.

# %%
a=2
b=3

# %%
a+b
# Out:
# 5

# %% [markdown]
# Variables can be named just about anything

# %%
Dallas=2
SMU=7
Texas_TX=3

# %%
#Note: that if we assign a value to a variable, our notebook won't return that value to our screen.
#If we want it to show us the value, we can call that variable after it is assigned.
ouranswer = SMU*Dallas*Texas_TX
ouranswer
# Out:
# 42

# %% [markdown]
# So far we have been doing all of our operations on numbers, integers and floats (decimals), but there are other useful objects we can use in Python.
#
# Strings allow us to store and operate on text data. Strings in Python are surrounded by either single quotes '' or double quotes "".

# %%
ourstring = "Here is a string in Python!"
ourstring
# Out:
# 'Here is a string in Python!'

# %% [markdown]
# If we later want to see the value stored in a variable we can always use the built in **print** function. **Print** is recognized as a keyword by our notebook and so the color changes to make our lives as programmers easier.

# %%
print(ourstring)
# Out:
# Here is a string in Python!

# %% [markdown]
# What if we want to have multiple strings stored at once but we don't want to assign a bunch of variables? Then we can use a list.
#
# Lists are enclosed by brackets [] and separated by commas.

# %%
ourlist = ['This', 'is', "a", "list", 'of', "strings"]

# %%
print(ourlist)
# Out:
# ['This', 'is', 'a', 'list', 'of', 'strings']

# %% [markdown]
# To access individual elements in a list you call it by its reference number.
#
# *__Note:__ In Python, counting starts with 0. Thus in the list [a,b,c], a is the 0th element and c is the 2nd*

# %%
first = ourlist[0]

# %%
# Notice we can call the last element by using a negative reference number. This lets us see the end without knowing how long the list is.
last = ourlist[-1]

# %%
print(first,last)
# Out:
# This strings

# %%
# If we did want to know the length of our list we can use the len() function
len(ourlist)
# Out:
# 6

# %% [markdown]
# ### Dictionaries

# %% [markdown]
# Dictionaries are a different way of storing data than lists. They rely on a key and value system as opposed to the order of the entries.
#
# Dictionaries are enclosed in curly braces {}, the key and value are separated by a colon : and entries are separated by commas ,
#
# Values can then be accessed by referencing the key.
#
# Note that finding dictionary values does not go both ways, so using the value to find the key will cause an error.

# %%
ourdictionary = {"Dallas":1345000,"Plano":286143,"Taos":5668,'Houston':2326000}
ourdictionary
# Out:
# {'Dallas': 1345000, 'Plano': 286143, 'Taos': 5668, 'Houston': 2326000}

# %%
ourdictionary["Taos"] 
#NOTE: ourdictionary[5668] will NOT give you "Taos", but an error.
# Out:
# 5668

# %% [markdown]
# Here are the word counts for the *Lord of the Rings* books ([citation](http://lotrproject.com/statistics/books/wordscount)). We will use this data for some exercises below.
#
# |__Book__|__Word Count__|
# |---|---|
# |The Silmarillion|130115|
# |The Hobbit|95506|
# |The Fellowship of the Ring|187726|
# |The Two Towers|156147|
# |The Return of the King|137037|

# %%
tolkien = {"The Silmarillion":130115,"The Hobbit":95506,"The Fellowship of the Ring":187726, "The Two Towers":156147, "The Return of the King":137037}

bilbo=tolkien["The Hobbit"]

frodo=tolkien["The Fellowship of the Ring"]

print("The Fellowship of the Ring - The Hobbit")

print(frodo-bilbo)

print("Total Words for the Lord of the Rings Trilogy")

print(tolkien["The Fellowship of the Ring"]+tolkien["The Two Towers"]+tolkien["The Return of the King"])
# Out:
# The Fellowship of the Ring - The Hobbit
# 92220
# Total Words for the Lord of the Rings Trilogy
# 480910

# %% [markdown]
# ## Loops and Functions

# %% [markdown]
# Computers are much better at doing simple repeatable tasks than humans are so to leverage this advantage, we will cover two different ways of writing these kind of repeatable instructions.

# %% [markdown]
# ### Loops

# %% [markdown]
# Loops are a way of having Python complete a task over and over.
#
# The most common form if a **for** loop. A **for** loop completes a task a fixed number of times by iterating a variable over the members of a sequence in order.

# %%
#Example for loop
for i in [0,1,2]:
    print(i)
# Out:
# 0
# 1
# 2

# %% [markdown]
# **Note**: The indention is important, it tells Python that the line *print(i)* belongs inside the loop.

# %% [markdown]
# ### Functions

# %% [markdown]
# Sometimes it would be nice to be able to save a group of instructions in a single block, that way we won't need to rewrite several lines of code each time we want to do that set of operations.
#
# To do this we define a **function**.
#
# Functions allow us to define a more complicated set of instructions as a single entity and call that entire block of code directly.
#
# Functions are defined (*def*), named (lowercase is a standard practice) and accept arguments (). They then can return a value if needed (*return*).
#
# Python has several built in functions (*print()* is a good example) and when you combine external packages and libraries, there are functions for just about everything you could think of.

# %%
# Example function
def square_me(n):
    return n*n

# %%
square_me(4)
# Out:
# 16

# %% [markdown]
# Putting loops and functions together is where python can become very powerful.

# %%
# Looping over a function
for i in [0,1,2,3]:
    print(square_me(i)) # note that this is still tabbed in within the for loop
# Out:
# 0
# 1
# 4
# 9

# %%
# A function with a loop
def print_numbers(start,stop):
    for i in range(start,stop): #Here the range() function gives us all the values from start up to but excluding the stop value
        print(i) # this is indented twice, so Python knows it is within the loop within the function

# %%
print_numbers(0,4)
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# ## Libraries

# %% [markdown]
# Libraries are pre-written chunks of code designed to be integrated into projects for a specific purpose.  The idea is to keep people from having to reinvent the wheel every time they want to write a program.  When we encounter situations where a libary might be useful, we use the keyword *import* to tell the program that we want to use this pre-existing code.  As an example, in the next section you will use a library called Pandas which helps visualize data and make it easier to digest, which is very useful for us.  Because of this, we will import that code into this program simply by running the cell with the import that goes with that code.  Here is what you will see, only in commented code.

# %%
#import pandas as pd

#by using the keyword *as* and giving pandas an alternative name (pd) in this program, it allows us to use the
#functions within pandas while only having to type our pd instead of pandas every time.

# %% [markdown]
# Most programming languages have libraries that allow you to import code this way, and it will save you a lot of time and allow you to quickly use many new functions that are highly polished.

# %% [markdown]
# ## DataFrames and Pandas

# %% [markdown]
# Now it is time to use what we have learned to start doing some data science.
#
# Pandas is the name of a library in which there are functions and tools for doing operations common in data analysis and data science. One particularly great feature is the DataFrame structure which allows us to work with an object similar to an Excel spreadsheet but with the flexibility and power of Python behind it.
#
# First we will need to import the Pandas library and create a DataFrame. DataFrames are can also be created when you import files (like CSV's) or tables from a database (like SQL).

# %%
import pandas as pd

# %%
#Notice here the data is a dictionary, similar to the one we used above but with the titles and wordcounts as nested lists
d = {"Books":["The Silmarillion","The Hobbit","The Fellowship of the Ring","The Two Towers","The Return of the King"],
     "Words":[130115,95506,187726,156147,137037]
    }
df = pd.DataFrame(d)
df
# Out:
#                         Books   Words
# 0            The Silmarillion  130115
# 1                  The Hobbit   95506
# 2  The Fellowship of the Ring  187726
# 3              The Two Towers  156147
# 4      The Return of the King  137037

# %% [markdown]
# Now we can operate on entire rows or columns in our DataFrame.

# %%
df["Books"] #Selecting the column "Books"
# Out:
# 0              The Silmarillion
# 1                    The Hobbit
# 2    The Fellowship of the Ring
# 3                The Two Towers
# 4        The Return of the King
# Name: Books, dtype: object

# %%
df[:2] #Selecting the first 2 rows
# Out:
#               Books   Words
# 0  The Silmarillion  130115
# 1        The Hobbit   95506

# %%
df[2:4] #Selecting rows 2 up to 4
# Out:
#                         Books   Words
# 2  The Fellowship of the Ring  187726
# 3              The Two Towers  156147

# %%
df["Words"][2:4] #Selecting the second and third row from the "Words" column.
# Out:
# 2    187726
# 3    156147
# Name: Words, dtype: int64

# %%
df[2:4]["Words"] #Same result but from the opposite order
# Out:
# 2    187726
# 3    156147
# Name: Words, dtype: int64

# %% [markdown]
# You can also operate on entire columns in your DataFrame. Just be careful because this can give you unexpected results. Rows are generally more consistent for elements within a DataFrame.

# %%
total = sum(df["Words"])
total
# Out:
# 706531

# %% [markdown]
# ## Plotting

# %% [markdown]
# Visualizing data is incredibly important when trying to convey findings. There are several libraries available for doing data visualization. Pandas has some built in plotting functionality, but we have provided access to MatPlotLib, Plotly and Seaborn as well.

# %%
# This is only needed in this case because we wanted to show the names of the books. You could make a similar plot in Pandas.
import matplotlib as plt

# %config InlineBackend.figure_format ='retina'

# %%
plot = df.plot(kind='bar') # we are setting the type of plot to a bar graph
plot.set_xticklabels(df['Books']); #This lets us rename the x axis labels

# %% [markdown]
# ## More Complex DataFrame Operations

# %% [markdown]
# To look at slightly more complex data operations, we need more complex data.
#
# Below we have all the chapters from the Hobbit and Lord of the Rings books along with their word counts. Notice that each chapter is a list of information and then each of those list is an element in a larger list.

# %% [markdown]
# ### More Complex Data

# %%
chapters = [[0,1,'An Unexpected Party',8638,0],
            [0,2,'Roast Mutton',5257,0],
            [0,3,'A Short Rest',2876,0],
            [0,4,'Over Hill and Under Hill',4034,0],
            [0,5,'Riddles in the Dark',6967,0],
            [0,6,'Out of the Frying Pan into the Fire',6703,0],
            [0,7,'Queer Lodgings',9027,0],
            [0,8,'Flies and Spiders',10223,0],
            [0,9,'Barrels Out of Bond',5833,0],
            [0,10,'A Warm Welcome',3930,0],
            [0,11,'On the Doorstep',3001,0],
            [0,12,'Inside Information',7132,0],
            [0,13,'Not At Home',3909,0],
            [0,14,'Fire and Water',3236,0],
            [0,15,'The Gathering of the Clouds',3362,0],
            [0,16,'A Thief in the Night',2153,0],
            [0,17,'The Clouds Burst',3949,0],
            [0,18,'The Return Journey',2815,0],
            [0,19,'The Last Stage',2461,0],
            [1,-4,'Concerning Hobbits',3406,1],
            [1,-3,'Concerning Pipeweed',600,1],
            [1,-2,'Of the Ordering of the Shire',2431,1],
            [1,-1,'Note on the Shire Records',914,1],
            [1,1,'A Long-expected Party',10012,1],
            [1,2,'The Shadow of the Past',11311,1],
            [1,3,'Three is Company',9763,1],
            [1,4,'A Short Cut to Mushrooms',5957,1],
            [1,5,'A Conspiracy Unmasked',5196,1],
            [1,6,'The Old Forest',6502,1],
            [1,7,'In the House of Tom Bombadil',5501,1],
            [1,8,'Fog on the Barrow-downs',6694,1],
            [1,9,'At the Sign of the Prancing Pony',6251,1],
            [1,10,'Strider',5905,1],
            [1,11,'A Knife in the Dark',9468,1],
            [1,12,'Flight to the Ford',8805,1],
            [1,1,'Many Meetings',9085,2],
            [1,2,'The Council of Elrond',16360,2],
            [1,3,'The Ring goes South',10656,2],
            [1,4,'A Journey in the Dark',11501,2],
            [1,5,'The Bridge of Khazad-dum',5428,2],
            [1,6,'Lothlorien',9387,2],
            [1,7,'The Mirror of Gladriel',6896,2],
            [1,8,'Farewell to Lorien',6174,2],
            [1,9,'The Great River',7218,2],
            [1,10,'The Breaking of the Fellowship',6305,2],
            [2,1,'The Departure of Boromir',3397,3],
            [2,2,'The Riders of Rohan',11133,3],
            [2,3,'The Uruk-hai',7854,3],
            [2,4,'Treebeard',12876,3],
            [2,5,'The White Rider',8856,3],
            [2,6,'The King of the Golden Hall',9303,3],
            [2,7,"Helm's Deep",7575,3],
            [2,8,'The Road to Isengard',7899,3],
            [2,9,'Flotsam and Jetsam',7789,3],
            [2,10,'The Voice of Saruman',5663,3],
            [2,11,'The Palantir',6325,3],
            [2,1,'The Taming of Smeagol',8375,4],
            [2,2,'The Passage of the Marshes',7357,4],
            [2,3,'The Black Gate is Closed',5881,4],
            [2,4,'Of Herbs and Stewed Rabbit',6975,4],
            [2,5,'The Window on the West',10120,4],
            [2,6,'The Forbidden Pool',5179,4],
            [2,7,'Journey to the Crossroads',4266,4],
            [2,8,'The Stairs of Cirith Ungol',6793,4],
            [2,9,"Shelob's Lair",5209,4],
            [2,10,'The Choices of Master Samwise',7322,4],
            [3,1,'Minas Tirith',13100,5],
            [3,2,'The Passing of the Grey Company',8586,5],
            [3,3,'The Muster of Rohan',6951,5],
            [3,4,'The Siege of Gondor',11793,5],
            [3,5,'The Ride of the Rohirrim',4358,5],
            [3,6,'The Battle of the Pelennor Fields',5225,5],
            [3,7,'The Pyre of Denethor',3736,5],
            [3,8,'The Houses of Healing',6731,5],
            [3,9,'The Last Debate',5416,5],
            [3,10,'The Black Gate Opens',5204,5],
            [3,1,'The Tower of Cirith Ungol',9721,6],
            [3,2,'The Land of Shadow',8446,6],
            [3,3,'Mount Doom',7777,6],
            [3,4,'The Field of Cormallen',4721,6],
            [3,5,'The Steward and the King',7639,6],
            [3,6,'Many Partings',7440,6],
            [3,7,'Homeward Bound',4106,6],
            [3,8,'The Scouring of the Shire',11296,6],
            [3,9,'The Grey Havens',4791,6]
           ]

# %% [markdown]
# Now we can turn the list of the lists into a dataframe. We have also named our columns. This isn't necessary but it does make things clearer to work with.

# %%
cols = ['CollectionNum','ChapterNum','ChapterName','WordCount','BookNum']
data = pd.DataFrame(chapters, columns=cols)

# %%
data
# Out:
#     CollectionNum  ChapterNum                ChapterName  WordCount  BookNum
# 0               0           1        An Unexpected Party       8638        0
# 1               0           2               Roast Mutton       5257        0
# 2               0           3               A Short Rest       2876        0
# 3               0           4   Over Hill and Under Hill       4034        0
# 4               0           5        Riddles in the Dark       6967        0
# ..            ...         ...                        ...        ...      ...
# 80              3           5   The Steward and the King       7639        6
# 81              3           6              Many Partings       7440        6
# 82              3           7             Homeward Bound       4106        6
# 83              3           8  The Scouring of the Shire      11296        6
# 84              3           9            The Grey Havens       4791        6
#
# [85 rows x 5 columns]

# %% [markdown]
# Now we might want to apply the names of each of the traditional "books" you might think of when you think about the Lord of the Rings. To do this we want to apply a function to each value in a column and save it into a new column. In this example, our "function" is using our *CollectionNum* to reference a book name in our list *titles*.

# %%
titles = ['The Hobbit','The Fellowship of the Ring', 'The Two Towers', 'The Return of the King']
data['CollectionName']=data['CollectionNum'].apply(lambda x: titles[x])

# %% [markdown]
# ### [GroupBy](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html)

# %% [markdown]
# Now that we have data for each of the chapters, we can group them using groupby. This lets us do aggregate operations like "add all the wordcounts for each book" or "count how many chapters there are in each book".
#
# Groupby is a powerful tool but if you don't understand your data, it can quickly introduce errors.

# %%
data.groupby(by='CollectionName').count()
# Out:
#                             CollectionNum  ChapterNum  ChapterName  WordCount  \
# CollectionName
# The Fellowship of the Ring             26          26           26         26
# The Hobbit                             19          19           19         19
# The Return of the King                 19          19           19         19
# The Two Towers                         21          21           21         21
#
#                             BookNum
# CollectionName
# The Fellowship of the Ring       26
# The Hobbit                       19
# The Return of the King           19
# The Two Towers                   21

# %%
data.groupby(by='CollectionName').sum()
# Out:
#                             CollectionNum  ChapterNum  WordCount  BookNum
# CollectionName
# The Fellowship of the Ring             26         123     187726       36
# The Hobbit                              0         190      95506        0
# The Return of the King                 57         100     137037      104
# The Two Towers                         42         121     156147       73

# %% [markdown]
# ### Selecting (Advanced Slicing)

# %% [markdown]
# You can select slices of your dataframe using conditional logic as well.

# %%
df
# Out:
#                         Books   Words
# 0            The Silmarillion  130115
# 1                  The Hobbit   95506
# 2  The Fellowship of the Ring  187726
# 3              The Two Towers  156147
# 4      The Return of the King  137037

# %%
# Select values based on exact matches
df[df['Books']=='The Hobbit']
# Out:
#         Books  Words
# 1  The Hobbit  95506

# %%
# Select values by negating a match
df[df['Books']!='The Hobbit']
# Out:
#                         Books   Words
# 0            The Silmarillion  130115
# 2  The Fellowship of the Ring  187726
# 3              The Two Towers  156147
# 4      The Return of the King  137037

# %%
# Select values containing substrings
df[df['Books'].str.contains('ing')]
# Out:
#                         Books   Words
# 2  The Fellowship of the Ring  187726
# 4      The Return of the King  137037

# %%
# Select values on multiple conditions using different columns
df[(df['Books'].str.contains('ing')) & (df['Words']>150000)]
# Out:
#                         Books   Words
# 2  The Fellowship of the Ring  187726

# %% [markdown]
# ### Joining (Mixing Data Sets)

# %% [markdown]
# You can also merge 2 dataframes if you want. Merging allows you to combine datasets in new ways and is a great tool to have when working with complex datasets.

# %% [markdown]
# First we need a second dataframe to work with. Here, we have made a dataframe with the publication year of each of of our Tolkien books.

# %%
df
# Out:
#                         Books   Words
# 0            The Silmarillion  130115
# 1                  The Hobbit   95506
# 2  The Fellowship of the Ring  187726
# 3              The Two Towers  156147
# 4      The Return of the King  137037

# %%
dates = pd.DataFrame({'Name':df['Books'],'Year':pd.Series([1977,1934,1954,1954,1954])})
dates
# NOTE: We named our column 'Name' for instructional purposes, but a better name would be 'Books' so that it matches my other dataframe.
#       Typically you want to use a unique identifier in your data and then merge based on that column.
# Out:
#                          Name  Year
# 0            The Silmarillion  1977
# 1                  The Hobbit  1934
# 2  The Fellowship of the Ring  1954
# 3              The Two Towers  1954
# 4      The Return of the King  1954

# %% [markdown]
# Now we can merge our new dates dataframe with our existing dataframe.
#
# We have done an inner join (only rows that match in both dataframes will appear in our join) where the column in the left dataframe is called "Books" and the column in the right dataframe is called "Name".
#
# More documentation on merging dataframes can be found [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html).

# %%
pd.merge(df,dates, left_on="Books", right_on="Name", how = 'inner')
# Out:
#                         Books   Words                        Name  Year
# 0            The Silmarillion  130115            The Silmarillion  1977
# 1                  The Hobbit   95506                  The Hobbit  1934
# 2  The Fellowship of the Ring  187726  The Fellowship of the Ring  1954
# 3              The Two Towers  156147              The Two Towers  1954
# 4      The Return of the King  137037      The Return of the King  1954

# %% [markdown]
# Notice that our merge duplicated our matching column because they had different names. This would not happen if we had the same name for columns in both dataframes. However, will not always be the case, so you can clean up your dataframe by dropping one of the redundant columns.

# %%
merged = pd.merge(df,dates, left_on="Books", right_on="Name", how = 'inner').drop(columns=['Name'])
merged
# Out:
#                         Books   Words  Year
# 0            The Silmarillion  130115  1977
# 1                  The Hobbit   95506  1934
# 2  The Fellowship of the Ring  187726  1954
# 3              The Two Towers  156147  1954
# 4      The Return of the King  137037  1954

# %% [markdown]
# ### More Complex Plotting

# %% [markdown]
# Lastly, we can combine several of the things we have learned into a single plot. Here we can group each book together and then look at the word counts by chapter throughout the story.

# %% [markdown]
# First, we want to come up with a way to step through the books in a linear way. We have provided a few ways to do this in increasing complexity.

# %%
# Simple - add the collection number to the chapter number divided by 10
#data['BookChapter'] = data['CollectionNum']+0.1*data['ChapterNum']

# Much better - add the book number to the chapter number divided by 10
#data['BookChapter'] = data['BookNum']+0.1*data['ChapterNum']

# Best but complicated - add the book number to the chapter number scaled by 1/n where n is the max number of chapters in that book.
data['BookChapter']=data.apply(lambda x: x['BookNum']+(1/data.groupby(by='BookNum').max()['ChapterNum'][x['BookNum']])*x['ChapterNum'], axis=1)

# %%
groups = data.groupby("CollectionName")

for name, group in groups:

    plt.pyplot.plot(group["BookChapter"], group["WordCount"],label=name)

plt.pyplot.legend()

# %% [markdown]
#  Notice that the prologue materials in *The Fellowship of the Ring* cause it to overlap with the *Hobbit*. If we wanted to resolve this, we would need to revisit our conventions in our data.

# %% [markdown]
# # Working with Data

# %% [markdown]
# ## Text as Data

# %% [markdown]
# A type of data that has become especially popular and powerful to investigate is text. Turns out there is a lot that we can learn by looking at what we write down. We'll spend more time working with text later in the class but for now, we'll just load the data and do some basic parsing.

# %%
example_text_file = "../example_data/folktales.csv"

df = pd.read_csv(example_text_file)

# %%
df
# Out:
#        ID  ATU Code                   Author Country of Origin  \
# 0      17      15.0    Jacob & Wilhelm Grimm           Germany
# 1      44     123.0    Jacob & Wilhelm Grimm           Germany
# 2      54     516.0    Jacob & Wilhelm Grimm           Germany
# 3      64       NaN    Jacob & Wilhelm Grimm           Germany
# 4      74     151.0    Jacob & Wilhelm Grimm           Germany
# ..    ...       ...                      ...               ...
# 903  9938    2023.0  Francesc Maspons Labrós             Spain
# 904  9939     780.0         Fernán Caballero             Spain
# 905  9940       NaN             Jean Cocteau            France
# 906  9941     222.0    Jacob & Wilhelm Grimm           Germany
# 907  9943       NaN          Nguyễn Đổng Chi           Vietnam
#
#                                Original Title  \
# 0              Katze und Maus in Gesellschaft
# 1    Der Wolf und die sieben jungen Geisslein
# 2                          Der treue Johannes
# 3                             Der gute Handel
# 4                   Der wunderliche Spielmann
# ..                                        ...
# 903                                 La rateta
# 904                             El lirio azul
# 905                                       NaN
# 906                 Der Zaunkönig und der Bär
# 907                       Chú Cuội Cung Trăng
#
#                                                 Source  \
# 0                                                  NaN
# 1                                                  NaN
# 2                         The Blue Fairy Book (nr. 30)
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 903                                                NaN
# 904                                                NaN
# 905                                                NaN
# 906  Jacob and Wilhelm Grimm. Household Tales. The ...
# 907                                                NaN
#
#                                                   Text  \
# 0    A cat had made the acquaintance of a mouse, an...
# 1    There was once an old goat who had seven littl...
# 2    ONCE upon a time there was an old king who was...
# 3    There was once a peasant who had driven his co...
# 4    There was once a wonderful musician, who went ...
# ..                                                 ...
# 903  Once upon a time, a purdy little mouse sat in ...
# 904  (Valencian version) Long, long ago, there was ...
# 905  The Gardiner and DeathA young Persian gardiner...
# 906  ONCE in summer-time the bear and the wolf were...
# 907  Long ago, at a certain village, there was Cuội...
#
#                                             Story Type  \
# 0         Stealing the Partner's Butter (ATU 15)\n\t\t
# 1     The Wolf and the Seven Young Kids (ATU 123)\n...
# 2                 The Petrified Friend (ATU 516)\n\t\t
# 3                                                  NaN
# 4       Music lessons for wild animals (ATU 151)\n\t\t
# ..                                                 ...
# 903   Little Ant Finds a Penny, Buys New Clothes wi...
# 904                   The Singing Bone (ATU 780)\n\t\t
# 905                                                NaN
# 906       The Willow-Wren and the Bear (ATU 222)\n\t\t
# 907                                                NaN
#
#                                  Title                  Translated  \
# 0         Cat and mouse in partnership               Margaret Hunt
# 1    The Wolf and the Seven Young Kids               Margaret Hunt
# 2                          Trusty John                 Andrew Lang
# 3                     The good bargain               Margaret Hunt
# 4               The Wonderful Musician     Translated into English
# ..                                 ...                         ...
# 903                          The Mouse  Jason F. Quackenbush, Esq.
# 904                      The Blue Lily              Amanda Cibulka
# 905             The gardiner and Death            Robert McConeghy
# 906       The Willow-Wren and the Bear     Jacob and Wilhelm Grimm
# 907                  Cuội and the Moon                     Koi Nil
#
#      Year Translated Year Written
# 0             1884.0         1812
# 1             1884.0         1812
# 2             1889.0         1812
# 3             1884.0         1812
# 4                NaN         1812
# ..               ...          ...
# 903           2016.0         1871
# 904           2017.0         1877
# 905           2016.0         1923
# 906           1909.0         1812
# 907           2017.0         1957
#
# [908 rows x 12 columns]

# %% [markdown]
# ### Exploring our Data

# %% [markdown]
# #### Question 1) What countries do we have stories from?

# %%
df['Country of Origin'].values
# Out:
# array(['Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Germany',
#        'Germany', 'Germany', 'Germany', 'Germany', 'Germany', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark',
#        'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Denmark', 'Russia',
#        'Russia', 'Russia', 'Russia', 'Russia', 'Russia', 'Russia',
#        'Russia', 'Russia', 'Russia', 'Russia', 'Russia', 'Russia',
#        'Russia', 'Russia', 'Russia', 'Russia', 'Russia', 'Russia',
#        'Russia', 'Russia', 'Russia', 'Russia', 'Russia', 'Russia',
#        'Russia', 'Russia', 'Russia', 'Russia', 'Russia', 'Russia',
#        'Russia', 'Russia', 'Russia', 'Russia', 'Russia', 'Russia',
#        'Russia', 'Norway', 'Norway', 'Norway', 'Norway', 'Norway',
#        'Norway', 'Norway', 'Norway', 'Norway', 'Norway', 'Norway',
#        'Norway', 'Norway', 'Norway', 'Norway', 'Norway', 'Norway',
#        'Norway', 'Norway', 'Norway', 'Norway', 'Norway', 'Norway',
#        'Norway', 'Norway', 'Norway', 'Norway', 'Norway', 'Norway',
#        'Norway', 'Norway', 'Norway', 'Norway', 'Norway', 'Norway',
#        'Norway', 'Norway', 'Norway', 'Norway', 'Norway', 'Norway',
#        'Norway', 'Norway', 'Norway', 'Norway', 'Norway', 'Norway',
#        'Norway', 'Norway', 'Norway', 'Norway', 'Norway', 'Norway',
#        'Norway', 'Norway', 'Norway', 'Norway', 'Norway', 'Norway',
#        'Norway', 'Norway', 'Norway', 'Norway', 'Norway', 'Norway',
#        'Norway', 'Norway', 'Norway', 'Norway', 'Norway', 'Norway',
#        'Norway', 'Norway', 'Norway', 'Norway', 'Norway', 'Norway',
#        'Norway', 'Norway', 'Norway', 'Norway', 'Norway', 'Norway',
#        'Norway', 'Norway', 'Norway', 'Norway', 'Norway', 'Norway',
#        'Norway', 'Norway', 'Norway', 'Norway', 'Norway', 'Norway',
#        'France', 'Italy', 'Italy', 'France', 'France', 'France', 'France',
#        'France', 'France', 'France', 'Italy', 'Italy', 'Italy', 'Italy',
#        'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy',
#        'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy',
#        'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy',
#        'Italy', 'Italy', 'Romania', 'Romania', 'Germany', 'Russia',
#        'Russia', 'Russia', 'Russia', 'Russia', 'Russia', 'Russia',
#        'Russia', 'Russia', 'Italy', 'Slovakia', 'Slovakia', 'Slovakia',
#        'Spain', 'Spain', 'Spain', 'Portugal', 'Germany', 'France',
#        'Russia', 'Russia', 'France', 'France', 'France', 'Surinam',
#        'Italy', 'Greece', 'Portugal', 'Spain', 'Greece', 'France',
#        'Greece', 'France', 'Spain \xa0 - Region', 'Spain \xa0 - Region',
#        'Spain \xa0 - Region', 'Spain \xa0 - Region',
#        'Spain \xa0 - Region', 'Germany', 'Germany', 'Germany', 'Greece',
#        'Italy', 'Italy', 'France', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Greece', 'Greece', 'Germany',
#        'Germany', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy',
#        'Italy', 'Portugal', 'Iceland', 'Iceland', 'Iceland', 'Iceland',
#        'Iceland', 'France', 'France', 'France', 'France', 'France',
#        'France', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy',
#        'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy',
#        'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy',
#        'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy',
#        'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy',
#        'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy',
#        'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy',
#        'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy',
#        'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy',
#        'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy', 'Italy',
#        'Italy', 'Italy', 'Russia', 'Russia', 'Russia', 'Ireland',
#        'Scotland', 'Russia', 'Iceland', 'Spain \xa0 - Region', 'Georgia',
#        'Portugal', 'Serbia', 'Greece', 'Italy', 'Greece', 'Russia',
#        'Russia', 'France', 'France', 'France', 'France', 'France',
#        'France', 'France', 'France', 'France', 'France', 'France',
#        'France', 'France', 'France', 'France', 'France', 'France',
#        'France', 'France', 'France', 'France', 'France', 'France',
#        'France', 'France', 'France', 'France', 'France', 'France',
#        'France', 'France', 'France', 'France', 'France', 'France',
#        'France', 'France', 'France', 'France', 'France', 'France',
#        'France', 'Italy', 'Italy', 'France', 'France', 'Greece', 'Russia',
#        'Ghana', 'Russia', 'Spain', 'England', 'Thailand', 'Greece',
#        'Greece', 'Greece', 'Greece', 'Algeria', 'Greece', 'Armenia',
#        'India', 'England', nan, 'France', 'Iran', 'France', 'Norway',
#        'France', 'Germany', 'Norway', 'France', 'France', 'France',
#        'France', 'Norway', 'Germany', 'France', 'Norway', 'France',
#        'South Africa', 'Spain', 'France', 'France', 'Mali',
#        'Democratic Republic of Congo', 'Democratic Republic of Congo',
#        'Democratic Republic of Congo', 'Aruba', 'France', 'Switserland',
#        'England \xa0 - Region', 'Greece', 'France', 'Zambia', 'Spain',
#        'Russia', 'Somalia', 'Italy', 'Zambia', 'Zambia', 'Zambia',
#        'Spain', 'Spain', 'France', 'Germany', 'Vietnam'], dtype=object)

# %%
# How about a more compressed list
df['Country of Origin'].value_counts()
# Out:
# Greece                          202
# Germany                         159
# Denmark                         138
# Italy                           115
# Norway                           99
# France                           79
# Russia                           58
# Spain                             9
# Spain   - Region                  6
# Iceland                           6
# Portugal                          4
# Zambia                            4
# Democratic Republic of Congo      3
# Slovakia                          3
# Romania                           2
# England                           2
# South Africa                      1
# Scotland                          1
# England   - Region                1
# Serbia                            1
# Somalia                           1
# Mali                              1
# Surinam                           1
# Ireland                           1
# India                             1
# Georgia                           1
# Algeria                           1
# Ghana                             1
# Iran                              1
# Aruba                             1
# Switserland                       1
# Vietnam                           1
# Thailand                          1
# Armenia                           1
# Name: Country of Origin, dtype: int64

# %% [markdown]
# #### Question 2) What fraction of my stories were written by the Brothers Grimm?

# %%
total_stories = len(df)
total_stories
# Out:
# 908

# %%
grimm = len(df[(df['Author'].str.contains('Grimm'))==True])
grimm
# Out:
# 159

# %%
grimm/total_stories
# Out:
# 0.1751101321585903

# %% [markdown]
# #### Question 3) How many titles contain animals?

# %% [markdown]
# How would I even do this?

# %%
df['Title'].str.contains('animals').value_counts()
# Out:
# False    908
# Name: Title, dtype: int64

# %%
df[df['Title'].str.contains('Wol')]['Title']
# Out:
# 1             The Wolf and the Seven Young Kids
# 291                       The Wolf and the Goat
# 324                Tsarevich Ivan and Grey Wolf
# 495                        The Ass and the Wolf
# 504                       The Wolf and the Lamb
# 506                        The Ass and the Wolf
# 508                       The Wolf and the Lamb
# 515                      The Wolf and the Crane
# 545                    The Wolves and the Sheep
# 552                   The Shepherd and the Wolf
# 564                      The Wolf and the Sheep
# 578                   The Wolf and the Housedog
# 616                The Wolves and the Sheepdogs
# 630                        The Kid and the Wolf
# 632                   The Wolf and the Shepherd
# 635                       The Wolf and the Goat
# 642                      The Wolf and the Horse
# 648             The Lion, the Wolf, and the Fox
# 649                       The Wolf and the Lion
# 664                     The Mother and the Wolf
# 671                       The Wolf and the Lion
# 681                       The Lamb and the Wolf
# 690             The Shepherd's Boy and the Wolf
# 715                       The Wolf and the Lamb
# 716    The Wolf and Fox, with the Ape for Judge
# 722           The Sheep, the Stag, and the Wolf
# 723            The Sheep, the Dog, and the Wolf
# 739                          The Wolf and Crane
# 757                        The Dog and the Wolf
# 833            The Wolf and the Fox In the Well
# 835                        The Wolf and the Fox
# 890                     The Lion, Wolf, and Fox
# Name: Title, dtype: object

# %% [markdown]
# That clearly doesn't seem like what the question is asking... Maybe this isn't something we can answer. Why not? What would we need to answer this question?

# %% [markdown]
# ## Working with Messy Data

# %% [markdown]
# Sometimes our data can be so messy that it is nearly impossible to work with.

# %%
messy_file="../example_data/messy_data.csv"

messy = pd.read_csv(messy_file,delimiter=";")
messy
# Out:
#                               Name            Air_Date  Age         Height  \
# 0                      Darth Vader           5/25/1977   41          1.88m
# 1         Picard, Captain Jean-Luc  September 28, 1987   59          173cm
# 2             Princess Leia Organa          25/05/1977   19           4.9'
# 3                             Yoda          21-05-1980  899            2.2
# 4                   Kirk, James T.    8 September 1966   34           6'2"
# 5                   Luke Skywalker          25/05/1977   19            5.6
# 6                            Spock    8 September 1966   35             6'
# 7                        Solo, Han           5/25/1977   32          5.9ft
# 8          Captain Kathryn Janeway    January 16, 1995   35          1.65m
# 9  Din Djarin, aka The Mandalorian          2019/11/12   36  5foot11inches
#
#                Ship                                               Text
# 0    The Death Star                               No, I am your father
# 1    USS Enterprise                                     Earl Grey, Hot
# 2        Tantive-IV      Aren't you a little short for a Stormtrooper?
# 3               NaN                      Do or do not, there is no try
# 4    uss enterprise                                        Khannnnn!!!
# 5            X-wing  But I was going into Tosche Station to pick up...
# 6          NCC-1701                              Live long and prosper
# 7  Millineum Falcon  Hokey religions and ancient weapons are no mat...
# 8       USS VOYAGER                                                NaN
# 9        RaZoRcReSt                                    This is the way

# %% [markdown]
# Let's just look at this data. How many data issues can you find that would hinder an analysis? How would you handle it?

# %% [markdown]
# ## Tricks for messy data

# %% [markdown]
# #### Names

# %% [markdown]
# One common problem is that names tend to be really bad ways to identify people. Why is that?
#
# A solution to this is to use something called a unique identifier (think your SMU ID number). A unique identifier can be used instead of a name because it will have a standard format and generally can be used to link an individual across multiple data sets. If used properly it can also be a good way to de-identify individuals.

# %%
import random
messy['uID'] = [str(random.randint(0,1000)).zfill(4) for i in range(len(messy))]
messy
# Out:
#                               Name            Air_Date  Age         Height  \
# 0                      Darth Vader           5/25/1977   41          1.88m
# 1         Picard, Captain Jean-Luc  September 28, 1987   59          173cm
# 2             Princess Leia Organa          25/05/1977   19           4.9'
# 3                             Yoda          21-05-1980  899            2.2
# 4                   Kirk, James T.    8 September 1966   34           6'2"
# 5                   Luke Skywalker          25/05/1977   19            5.6
# 6                            Spock    8 September 1966   35             6'
# 7                        Solo, Han           5/25/1977   32          5.9ft
# 8          Captain Kathryn Janeway    January 16, 1995   35          1.65m
# 9  Din Djarin, aka The Mandalorian          2019/11/12   36  5foot11inches
#
#                Ship                                               Text   uID
# 0    The Death Star                               No, I am your father  0699
# 1    USS Enterprise                                     Earl Grey, Hot  0913
# 2        Tantive-IV      Aren't you a little short for a Stormtrooper?  0693
# 3               NaN                      Do or do not, there is no try  0335
# 4    uss enterprise                                        Khannnnn!!!  0450
# 5            X-wing  But I was going into Tosche Station to pick up...  0256
# 6          NCC-1701                              Live long and prosper  0879
# 7  Millineum Falcon  Hokey religions and ancient weapons are no mat...  0775
# 8       USS VOYAGER                                                NaN  0309
# 9        RaZoRcReSt                                    This is the way  0182

# %%
messy[['uID','Age','Ship']]
# Out:
#     uID  Age              Ship
# 0  0699   41    The Death Star
# 1  0913   59    USS Enterprise
# 2  0693   19        Tantive-IV
# 3  0335  899               NaN
# 4  0450   34    uss enterprise
# 5  0256   19            X-wing
# 6  0879   35          NCC-1701
# 7  0775   32  Millineum Falcon
# 8  0309   35       USS VOYAGER
# 9  0182   36        RaZoRcReSt

# %% [markdown]
# There is a lot to unpack with what we did there, let's break that down:
#
# - First we're generating a list using a single line for loop
# - Our loop is over the elements in the range that goes from 0 to the length of our data frame - effectively saying make the list the same length as our dataframe
# - Then our loop generates a random integer from 0 to 1000 but we needed to import python's random number generator to do that for us
# - Then we want to convert our random integer to a string. We wouldn't want to accidentally do math with our unique ID numbers
# - We want to make sure our IDs are all the same length using zfill to add 0s to the front of our string. This is common for numbers like this. Just think of your credit card number, social security number, SMU ID....
# - Lastly, we assign our list to the new column in our dataframe 'uID'

# %%
# The same code but unpacked
import random

ll = [] #initialize an empty list
length = len(messy)
for i in range(0,length):
    r = random.randint(0,1000)
    s = str(r)
    s4 = s.zfill(4)
    ll.append(s4) # This lets us add elements to a list
messy['uID']=ll
messy
# Out:
#                               Name            Air_Date  Age         Height  \
# 0                      Darth Vader           5/25/1977   41          1.88m
# 1         Picard, Captain Jean-Luc  September 28, 1987   59          173cm
# 2             Princess Leia Organa          25/05/1977   19           4.9'
# 3                             Yoda          21-05-1980  899            2.2
# 4                   Kirk, James T.    8 September 1966   34           6'2"
# 5                   Luke Skywalker          25/05/1977   19            5.6
# 6                            Spock    8 September 1966   35             6'
# 7                        Solo, Han           5/25/1977   32          5.9ft
# 8          Captain Kathryn Janeway    January 16, 1995   35          1.65m
# 9  Din Djarin, aka The Mandalorian          2019/11/12   36  5foot11inches
#
#                Ship                                               Text   uID
# 0    The Death Star                               No, I am your father  0013
# 1    USS Enterprise                                     Earl Grey, Hot  0591
# 2        Tantive-IV      Aren't you a little short for a Stormtrooper?  0500
# 3               NaN                      Do or do not, there is no try  0025
# 4    uss enterprise                                        Khannnnn!!!  0507
# 5            X-wing  But I was going into Tosche Station to pick up...  0378
# 6          NCC-1701                              Live long and prosper  0509
# 7  Millineum Falcon  Hokey religions and ancient weapons are no mat...  0556
# 8       USS VOYAGER                                                NaN  0473
# 9        RaZoRcReSt                                    This is the way  0784

# %% [markdown]
# #### Dates

# %% [markdown]
# Another common issue is that there are lots of formats for dates and times. This isn't just an issue with personal data but is one that can cause huge headaches when working with data sets. Even asking simple questions can become complicated when working with dates if you aren't sure of the formatting.
#
# Think about all the steps your brain makes if I ask you what the date was 3 weeks ago?

# %% [markdown]
# Somewhat incredibly, pandas can actually recognize several forms of dates and guess what the date formats are and convert them to a standardize format using the function [to_datetime](https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html?highlight=to_datetime#pandas.to_datetime).

# %%
messy['Date_Fixed'] = pd.to_datetime(messy['Air_Date'],errors='raise')
messy[['Air_Date','Date_Fixed']]
# Out:
#              Air_Date Date_Fixed
# 0           5/25/1977 1977-05-25
# 1  September 28, 1987 1987-09-28
# 2          25/05/1977 1977-05-25
# 3          21-05-1980 1980-05-21
# 4    8 September 1966 1966-09-08
# 5          25/05/1977 1977-05-25
# 6    8 September 1966 1966-09-08
# 7           5/25/1977 1977-05-25
# 8    January 16, 1995 1995-01-16
# 9          2019/11/12 2019-11-12

# %% [markdown]
# #### Missing Values

# %% [markdown]
# Another problem we can encounter is missing data. This happens all the time with "wild data" and can happen for numerous reasons, for example:
# - no data should exist for a reason
# - an error in the data creation
# - an operation induced the missing data
#
# Pandas has a simple function to handle this called [fillna](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html).

# %%
messy = messy.fillna('No Data Available') #Note this will change our data
messy
# Out:
#                               Name            Air_Date  Age         Height  \
# 0                      Darth Vader           5/25/1977   41          1.88m
# 1         Picard, Captain Jean-Luc  September 28, 1987   59          173cm
# 2             Princess Leia Organa          25/05/1977   19           4.9'
# 3                             Yoda          21-05-1980  899            2.2
# 4                   Kirk, James T.    8 September 1966   34           6'2"
# 5                   Luke Skywalker          25/05/1977   19            5.6
# 6                            Spock    8 September 1966   35             6'
# 7                        Solo, Han           5/25/1977   32          5.9ft
# 8          Captain Kathryn Janeway    January 16, 1995   35          1.65m
# 9  Din Djarin, aka The Mandalorian          2019/11/12   36  5foot11inches
#
#                 Ship                                               Text   uID  \
# 0     The Death Star                               No, I am your father  0013
# 1     USS Enterprise                                     Earl Grey, Hot  0591
# 2         Tantive-IV      Aren't you a little short for a Stormtrooper?  0500
# 3  No Data Available                      Do or do not, there is no try  0025
# 4     uss enterprise                                        Khannnnn!!!  0507
# 5             X-wing  But I was going into Tosche Station to pick up...  0378
# 6           NCC-1701                              Live long and prosper  0509
# 7   Millineum Falcon  Hokey religions and ancient weapons are no mat...  0556
# 8        USS VOYAGER                                  No Data Available  0473
# 9         RaZoRcReSt                                    This is the way  0784
#
#   Date_Fixed
# 0 1977-05-25
# 1 1987-09-28
# 2 1977-05-25
# 3 1980-05-21
# 4 1966-09-08
# 5 1977-05-25
# 6 1966-09-08
# 7 1977-05-25
# 8 1995-01-16
# 9 2019-11-12

# %% [markdown]
# #### Case Sensitivity

# %% [markdown]
# Another common issue with dealing with messy data is case sensitivity. Since python sees 'A' and 'a' as two different characters, it is important to be aware of case sensitivity. The easiest way to do this is to send all the characters in a particular column to a single case pattern. Fortunately, pandas has a family of functions to do that for us. [lower](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.lower.html?highlight=lower#pandas.Series.str.lower) is a good example.

# %%
messy['Ship'] = messy['Ship'].str.lower()
messy
# Out:
#                               Name            Air_Date  Age         Height  \
# 0                      Darth Vader           5/25/1977   41          1.88m
# 1         Picard, Captain Jean-Luc  September 28, 1987   59          173cm
# 2             Princess Leia Organa          25/05/1977   19           4.9'
# 3                             Yoda          21-05-1980  899            2.2
# 4                   Kirk, James T.    8 September 1966   34           6'2"
# 5                   Luke Skywalker          25/05/1977   19            5.6
# 6                            Spock    8 September 1966   35             6'
# 7                        Solo, Han           5/25/1977   32          5.9ft
# 8          Captain Kathryn Janeway    January 16, 1995   35          1.65m
# 9  Din Djarin, aka The Mandalorian          2019/11/12   36  5foot11inches
#
#                 Ship                                               Text   uID  \
# 0     the death star                               No, I am your father  0013
# 1     uss enterprise                                     Earl Grey, Hot  0591
# 2         tantive-iv      Aren't you a little short for a Stormtrooper?  0500
# 3  no data available                      Do or do not, there is no try  0025
# 4     uss enterprise                                        Khannnnn!!!  0507
# 5             x-wing  But I was going into Tosche Station to pick up...  0378
# 6           ncc-1701                              Live long and prosper  0509
# 7   millineum falcon  Hokey religions and ancient weapons are no mat...  0556
# 8        uss voyager                                  No Data Available  0473
# 9         razorcrest                                    This is the way  0784
#
#   Date_Fixed
# 0 1977-05-25
# 1 1987-09-28
# 2 1977-05-25
# 3 1980-05-21
# 4 1966-09-08
# 5 1977-05-25
# 6 1966-09-08
# 7 1977-05-25
# 8 1995-01-16
# 9 2019-11-12

# %% [markdown]
# That might not actually be what we want but at least we can compare the values now.

# %%
messy['Ship'].value_counts()
# Out:
# uss enterprise       2
# uss voyager          1
# no data available    1
# ncc-1701             1
# the death star       1
# millineum falcon     1
# tantive-iv           1
# razorcrest           1
# x-wing               1
# Name: Ship, dtype: int64

# %% [markdown]
# ### Check Results

# %% [markdown]
# Let's look at our messy data before:

# %%
before = pd.read_csv(messy_file,delimiter=";")
before
# Out:
#                               Name            Air_Date  Age         Height  \
# 0                      Darth Vader           5/25/1977   41          1.88m
# 1         Picard, Captain Jean-Luc  September 28, 1987   59          173cm
# 2             Princess Leia Organa          25/05/1977   19           4.9'
# 3                             Yoda          21-05-1980  899            2.2
# 4                   Kirk, James T.    8 September 1966   34           6'2"
# 5                   Luke Skywalker          25/05/1977   19            5.6
# 6                            Spock    8 September 1966   35             6'
# 7                        Solo, Han           5/25/1977   32          5.9ft
# 8          Captain Kathryn Janeway    January 16, 1995   35          1.65m
# 9  Din Djarin, aka The Mandalorian          2019/11/12   36  5foot11inches
#
#                Ship                                               Text
# 0    The Death Star                               No, I am your father
# 1    USS Enterprise                                     Earl Grey, Hot
# 2        Tantive-IV      Aren't you a little short for a Stormtrooper?
# 3               NaN                      Do or do not, there is no try
# 4    uss enterprise                                        Khannnnn!!!
# 5            X-wing  But I was going into Tosche Station to pick up...
# 6          NCC-1701                              Live long and prosper
# 7  Millineum Falcon  Hokey religions and ancient weapons are no mat...
# 8       USS VOYAGER                                                NaN
# 9        RaZoRcReSt                                    This is the way

# %% [markdown]
# and after:

# %%
messy[["uID","Name","Date_Fixed","Age","Height","Ship","Text"]]
# Out:
#     uID                             Name Date_Fixed  Age         Height  \
# 0  0013                      Darth Vader 1977-05-25   41          1.88m
# 1  0591         Picard, Captain Jean-Luc 1987-09-28   59          173cm
# 2  0500             Princess Leia Organa 1977-05-25   19           4.9'
# 3  0025                             Yoda 1980-05-21  899            2.2
# 4  0507                   Kirk, James T. 1966-09-08   34           6'2"
# 5  0378                   Luke Skywalker 1977-05-25   19            5.6
# 6  0509                            Spock 1966-09-08   35             6'
# 7  0556                        Solo, Han 1977-05-25   32          5.9ft
# 8  0473          Captain Kathryn Janeway 1995-01-16   35          1.65m
# 9  0784  Din Djarin, aka The Mandalorian 2019-11-12   36  5foot11inches
#
#                 Ship                                               Text
# 0     the death star                               No, I am your father
# 1     uss enterprise                                     Earl Grey, Hot
# 2         tantive-iv      Aren't you a little short for a Stormtrooper?
# 3  no data available                      Do or do not, there is no try
# 4     uss enterprise                                        Khannnnn!!!
# 5             x-wing  But I was going into Tosche Station to pick up...
# 6           ncc-1701                              Live long and prosper
# 7   millineum falcon  Hokey religions and ancient weapons are no mat...
# 8        uss voyager                                  No Data Available
# 9         razorcrest                                    This is the way

# %% [markdown]
# # Preliminary Text Analysis

# %% [markdown]
# These are the basic libraries we will use in for data manipulation (pandas) and math functions (numpy). We will add more libraries as we need them.
#
# As a best practice, it is a good idea to load all your libraries in a single cell at the top of a notebook, however for the purposes of this tutorial we will load them as we go.

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(example_text_file) #if your filetype is not CSV, you may need to add " , sep = 'separating_character_here' " after the filename.  This may require extra manipulation, so be careful.
data.head() #We will use the .head() attribute to limit the amount of the DataFrame is displayed on screen. It is not necessary for computation.
# Out:
#    ID  ATU Code                 Author Country of Origin  \
# 0  17      15.0  Jacob & Wilhelm Grimm           Germany
# 1  44     123.0  Jacob & Wilhelm Grimm           Germany
# 2  54     516.0  Jacob & Wilhelm Grimm           Germany
# 3  64       NaN  Jacob & Wilhelm Grimm           Germany
# 4  74     151.0  Jacob & Wilhelm Grimm           Germany
#
#                              Original Title                        Source  \
# 0            Katze und Maus in Gesellschaft                           NaN
# 1  Der Wolf und die sieben jungen Geisslein                           NaN
# 2                        Der treue Johannes  The Blue Fairy Book (nr. 30)
# 3                           Der gute Handel                           NaN
# 4                 Der wunderliche Spielmann                           NaN
#
#                                                 Text  \
# 0  A cat had made the acquaintance of a mouse, an...
# 1  There was once an old goat who had seven littl...
# 2  ONCE upon a time there was an old king who was...
# 3  There was once a peasant who had driven his co...
# 4  There was once a wonderful musician, who went ...
#
#                                           Story Type  \
# 0       Stealing the Partner's Butter (ATU 15)\n\t\t
# 1   The Wolf and the Seven Young Kids (ATU 123)\n...
# 2               The Petrified Friend (ATU 516)\n\t\t
# 3                                                NaN
# 4     Music lessons for wild animals (ATU 151)\n\t\t
#
#                                Title               Translated  \
# 0       Cat and mouse in partnership            Margaret Hunt
# 1  The Wolf and the Seven Young Kids            Margaret Hunt
# 2                        Trusty John              Andrew Lang
# 3                   The good bargain            Margaret Hunt
# 4             The Wonderful Musician  Translated into English
#
#    Year Translated Year Written
# 0           1884.0         1812
# 1           1884.0         1812
# 2           1889.0         1812
# 3           1884.0         1812
# 4              NaN         1812

# %% [markdown]
# Here we can see all the information available to us from the file in the form of a Pandas DataFrame. For the remainder of this tutorial, we will focus primarily on the full text of each data chunk, which we will name the *Story* column.  With your data set this is likely to be something very different, so feel free to call is something else.

# %% [markdown]
# ### Counting Words and Characters

# %% [markdown]
# The first bit of analysis we might want to do is to count the number of words in one piece of data. To do this we will add a column called *wordcount* and write an operation that applies a function to every row of the column.
#
# Unpacking this piece of code, *len(str(x).split(" ")*, tells us what is happening.
#
# For the content of cell *x*, convert it to a string, *str()*, then split that string into pieces at each space, *split()*.
#
# The result of that is a list of all the words in the text and then we can count the length of that list, *len()*.

# %%
data['wordcount'] = data['Text'].apply(lambda x: len(str(x).split(" ")))
data[['Text','wordcount']].head()
# Out:
#                                                 Text  wordcount
# 0  A cat had made the acquaintance of a mouse, an...        987
# 1  There was once an old goat who had seven littl...       1037
# 2  ONCE upon a time there was an old king who was...       3068
# 3  There was once a peasant who had driven his co...       1723
# 4  There was once a wonderful musician, who went ...       1066

# %% [markdown]
# We can do something similar to count the number of characters in the data chunk, including spaces. If you wanted to exclude whitespaces, you could take the list we made above, join it together and count the length of the resulting string.

# %%
data = data.fillna("No Information Provided") #If some of our data is missing, this will replace the blank entries. This is only necessary in some cases

# %%
data['char_count'] = data['Text'].str.len() ## this also includes spaces, to do it without spaces, you could use something like this: "".join()
data[['Text','char_count']].head()
# Out:
#                                                 Text  char_count
# 0  A cat had made the acquaintance of a mouse, an...        5108
# 1  There was once an old goat who had seven littl...        5343
# 2  ONCE upon a time there was an old king who was...       15999
# 3  There was once a peasant who had driven his co...        8907
# 4  There was once a wonderful musician, who went ...        5592

# %% [markdown]
# Now we want to calculate the average word length in the data.
#
# Let's define a function that will do that for us:

# %%
def avg_word(sentence):
    words = sentence.split()
    return (sum(len(word) for word in words)/len(words))

# %% [markdown]
# We can now apply that function to all the data chunks and save that in a new column.

# %%
data['avg_word'] = data['Text'].apply(lambda x: avg_word(x))
data[['Text','avg_word']].head()
# Out:
#                                                 Text  avg_word
# 0  A cat had made the acquaintance of a mouse, an...  4.176292
# 1  There was once an old goat who had seven littl...  4.153327
# 2  ONCE upon a time there was an old king who was...  4.215124
# 3  There was once a peasant who had driven his co...  4.170052
# 4  There was once a wonderful musician, who went ...  4.246717

# %% [markdown]
# We can then sort by the average word length.

# %%
data[['Text','avg_word']].sort_values(by='avg_word', ascending=True).head()
# Out:
#                                                   Text  avg_word
# 659    A GNAT settled on the horn of a Bull, and sa...  3.623377
# 656    A MAN wished to purchase an Ass, and agreed ...  3.709924
# 620    A HOUND having started a Hare on the hillsid...  3.737374
# 391  Once on a time there was a little boy who was ...  3.771277
# 895  Hare once said to Elephant : " Let us play hid...  3.795652

# %% [markdown]
# ### Count Stopwords

# %% [markdown]
# Stopwords are words that are commonly used and do little to aid in the understanding of the content of a text. There is no universal list of stopwords and they vary on the style, time period and media from which your text came from.  Typically, people choose to remove stopwords from their data, as it adds extra clutter while the words themselves provide little to no insight as to the nature of the data.  For now, we are simply going to count them to get an idea of how many there are.
#
# For this tutorial, we will use the standard list of stopwords provided by the Natural Language Toolkit python library.

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /users/egodat/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %% [markdown]
# To count the number of stopwords in a chunk of data, we make a list of all the words in our data that are also in the stopword list. We can then just take the length of that list and store it in a new column

# %%
data['stopwords'] = data['Text'].apply(lambda x: len([x for x in x.split() if x in stop]))
data[['Text','stopwords','wordcount']].head()
# Out:
#                                                 Text  stopwords  wordcount
# 0  A cat had made the acquaintance of a mouse, an...        446        987
# 1  There was once an old goat who had seven littl...        505       1037
# 2  ONCE upon a time there was an old king who was...       1471       3068
# 3  There was once a peasant who had driven his co...        745       1723
# 4  There was once a wonderful musician, who went ...        470       1066

# %% [markdown]
# ### Other Ways to Count

# %% [markdown]
# There are other types of counting we might want to do. These might be more or less relevant depending on the test you are working with.
#
# For completeness, we have put them here but we will skip over them in this tutorial

# %% [markdown]
# #### Counting Special Characters

# %% [markdown]
# This is really only useful for Twitter or other Internet texts but you could imagine wanting to count quotations or exclamations with something similar.

# %%
data['special_char'] = data['Text'].apply(lambda x: len([x for x in x.split() if x.startswith('#')]))
data[['Text','special_char']].head()
# Out:
#                                                 Text  special_char
# 0  A cat had made the acquaintance of a mouse, an...             0
# 1  There was once an old goat who had seven littl...             0
# 2  ONCE upon a time there was an old king who was...             0
# 3  There was once a peasant who had driven his co...             0
# 4  There was once a wonderful musician, who went ...             0

# %% [markdown]
# #### Counting Numbers

# %% [markdown]
# This counts the number of numerical digits in a text, which for strict text may not be helpful, but mostly numerical data will make more use of this.

# %%
data['numerics'] = data['Text'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
data[['Text','numerics']].sort_values(by='numerics', ascending=False).head()
# Out:
#                                                   Text  numerics
# 416  Osborn’s PipeONCE on a time there was a poor t...         9
# 414  ONCE FIVE women were reaping in a field. Each ...         4
# 696  There was once a husband and a wife who had tw...         2
# 311  There once lived an old man who had three daug...         2
# 727  Whoever, to his honor's cost,His pristine dign...         1

# %% [markdown]
# #### Counting Uppercase

# %% [markdown]
# Counting uppercase words could give us an indication of how many sentences or proper nouns are in a text but this is likely too broad to be used to classify either on its own.

# %%
data['upper'] = data['Text'].apply(lambda x: len([x for x in x.split() if x.isupper()]))
data[['Text','upper']].head()
# Out:
#                                                 Text  upper
# 0  A cat had made the acquaintance of a mouse, an...     12
# 1  There was once an old goat who had seven littl...      5
# 2  ONCE upon a time there was an old king who was...     39
# 3  There was once a peasant who had driven his co...     35
# 4  There was once a wonderful musician, who went ...     19

# %% [markdown]
# # Processing Text for Analysis

# %% [markdown]
# A major component of doing analysis on text is the cleaning of the text prior to the analysis.
#
# Though this process destroys some elements of the text (sentence structure, for example), it is often necessary in order to describe a text analytically. Depending on your choice of cleaning techniques, some elements might be preserved better than others if that is of importance to your analysis.

# %% [markdown]
# ## Cleaning Up Words

# %% [markdown]
# This series of steps aims to clean up and standardize the text itself. This generally consists of removing common elements such as stopwords and punctuation but can be expanded to more detailed removals.

# %% [markdown]
# ### Lowercase

# %% [markdown]
# Here we enforce that all of the text is lowercase. This makes it easier to match cases and sort words.
#
# Notice we are assigning our modified column back to itself. This will save our modifications to our DataFrame

# %%
data['Text'] = data['Text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
data['Text'].head()
# Out:
# 0    a cat had made the acquaintance of a mouse, an...
# 1    there was once an old goat who had seven littl...
# 2    once upon a time there was an old king who was...
# 3    there was once a peasant who had driven his co...
# 4    there was once a wonderful musician, who went ...
# Name: Text, dtype: object

# %% [markdown]
# ### Remove Punctuation

# %% [markdown]
# Here we remove all punctuation from the data. This allows us to focus on the words only as well as assist in matching.

# %%
data['Text'] = data['Text'].str.replace('[^\w\s]','')
data['Text'].head()
# Out:
# <ipython-input-86-5a2099d0f9da>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Text'] = data['Text'].str.replace('[^\w\s]','')
# 0    a cat had made the acquaintance of a mouse and...
# 1    there was once an old goat who had seven littl...
# 2    once upon a time there was an old king who was...
# 3    there was once a peasant who had driven his co...
# 4    there was once a wonderful musician who went q...
# Name: Text, dtype: object

# %% [markdown]
# ### Remove Stopwords

# %% [markdown]
# Similar to what we did earlier when we counted stopwords, we now want to remove the stopwords. We will again use the NLTK list of stopwords but this time keep a list of words that do not appear in the list of stopwords.

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
data['Text'] = data['Text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
data['Text'].head()
# Out:
# 0    cat made acquaintance mouse said much great lo...
# 1    old goat seven little ones fond ever mother ch...
# 2    upon time old king ill thought likely deathbed...
# 3    peasant driven cow fair sold seven thalers way...
# 4    wonderful musician went quite alone forest tho...
# Name: Text, dtype: object

# %% [markdown]
# ### Remove Frequent Words

# %% [markdown]
# If we want to catch common words that might have slipped through the stopword removal, we can build out a list of the most common words remaining in our text.
#
# Here we have built a list of the 10 most common words. Some of these words might actually be relevant to our analysis so it is important to be careful with this method.

# %%
freq = pd.Series(' '.join(data['Text']).split()).value_counts()[:10]
freq
# Out:
# said      9644
# one       4980
# came      3502
# little    3489
# went      3317
# could     3040
# would     3023
# king      2846
# old       2764
# man       2375
# dtype: int64

# %% [markdown]
# We now follow the same procedure with which we removed stopwords to remove the most frequent words.

# %%
freq = list(freq.index)
data['Text'] = data['Text'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
data['Text'].head()
# Out:
# 0    cat made acquaintance mouse much great love fr...
# 1    goat seven ones fond ever mother children day ...
# 2    upon time ill thought likely deathbed send tru...
# 3    peasant driven cow fair sold seven thalers way...
# 4    wonderful musician quite alone forest thought ...
# Name: Text, dtype: object

# %% [markdown]
# ### Remove Rare Words

# %% [markdown]
# By analogy, we can remove the most rare words. Some of these are strange misspellings or [hapax legomenon](https://en.wikipedia.org/wiki/Hapax_legomenon) (one off words that don't appear anywhere else in the text).

# %%
freq = pd.Series(' '.join(data['Text']).split()).value_counts()[-10:]
freq
# Out:
# worday          1
# genial          1
# whateversoon    1
# himlike         1
# onelet          1
# demandedand     1
# foiled          1
# ladtry          1
# bothbut         1
# vendelbo        1
# dtype: int64

# %% [markdown]
# Again, removing words following the same process as the stopword removal.

# %%
freq = list(freq.index)
data['Text'] = data['Text'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
data['Text'].head()
# Out:
# 0    cat made acquaintance mouse much great love fr...
# 1    goat seven ones fond ever mother children day ...
# 2    upon time ill thought likely deathbed send tru...
# 3    peasant driven cow fair sold seven thalers way...
# 4    wonderful musician quite alone forest thought ...
# Name: Text, dtype: object

# %% [markdown]
# ### Tokenization

# %% [markdown]
# Tokenization is the process of splitting up a block of text into a sequence of words or sentences.
#
# For those familiar with R and the Tidyverse, this would be referred to as unnesting tokens
#
# Here we show all the tokenized words from the first data chunk in our Dataframe.

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /users/egodat/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from textblob import TextBlob

TextBlob(data['Text'][0]).words
# Out:
# WordList(['cat', 'made', 'acquaintance', 'mouse', 'much', 'great', 'love', 'friendship', 'felt', 'last', 'mouse', 'agreed', 'live', 'keep', 'house', 'together', 'must', 'make', 'preparations', 'winter', 'else', 'shall', 'suffer', 'hunger', 'cat', 'mouse', 'can', 'not', 'venture', 'everywhere', 'end', 'caught', 'trap', 'good', 'advice', 'followed', 'bought', 'pot', 'fat', 'know', 'store', 'finally', 'much', 'consideration', 'cat', 'know', 'place', 'better', 'stored', 'church', 'dares', 'take', 'anything', 'away', 'put', 'beneath', 'altar', 'touch', 'need', 'pot', 'stored', 'safely', 'away', 'long', 'cat', 'took', 'great', 'longing', 'mouse', 'wanted', 'tell', 'mouse', 'cousin', 'brought', 'son', 'world', 'asked', 'godfather', 'white', 'brown', 'spots', 'hold', 'baptismal', 'font', 'let', 'go', 'today', 'look', 'house', 'yes', 'yes', 'answered', 'mouse', 'means', 'go', 'get', 'anything', 'good', 'eat', 'think', 'like', 'drink', 'drop', 'sweet', 'red', 'christening', 'wine', 'however', 'untrue', 'cat', 'cousin', 'asked', 'godfather', 'straight', 'church', 'crept', 'pot', 'fat', 'began', 'lick', 'licked', 'top', 'fat', 'stroll', 'roofs', 'town', 'looked', 'opportunities', 'stretched', 'sun', 'licking', 'whiskers', 'whenever', 'thought', 'pot', 'fat', 'return', 'home', 'evening', 'well', 'mouse', 'must', 'happy', 'day', 'everything', 'well', 'answered', 'cat', 'name', 'give', 'child', 'asked', 'mouse', 'topoff', 'cat', 'quite', 'coolly', 'topoff', 'cried', 'mouse', 'odd', 'uncommon', 'name', 'usual', 'family', 'matter', 'cat', 'worse', 'crumbthief', 'godchildren', 'calledbefore', 'long', 'cat', 'seized', 'another', 'fit', 'longing', 'mouse', 'must', 'favor', 'manage', 'house', 'alone', 'day', 'asked', 'godfather', 'since', 'child', 'white', 'ring', 'around', 'neck', 'can', 'not', 'refuse', 'good', 'mouse', 'consented', 'however', 'cat', 'crept', 'behind', 'town', 'wall', 'church', 'devoured', 'half', 'pot', 'fat', 'nothing', 'tastes', 'good', 'eats', 'oneself', 'quite', 'satisfied', 'days', 'work', 'arrived', 'home', 'mouse', 'asked', 'name', 'child', 'christened', 'halfgone', 'answered', 'cat', 'halfgone', 'saying', 'never', 'heard', 'name', 'life', 'ill', 'wager', 'almanacthe', 'cats', 'mouth', 'soon', 'began', 'water', 'delicious', 'goods', 'good', 'things', 'come', 'threes', 'mouse', 'asked', 'godfather', 'child', 'totally', 'black', 'white', 'paws', 'otherwise', 'single', 'white', 'hair', 'whole', 'body', 'happens', 'every', 'years', 'let', 'go', 'wont', 'topoff', 'halfgone', 'answered', 'mouse', 'odd', 'names', 'make', 'stop', 'think', 'sit', 'home', 'cat', 'dark', 'gray', 'fur', 'coat', 'long', 'braid', 'hair', 'capturing', 'fantasies', 'go', 'daytime', 'cats', 'absence', 'mouse', 'cleaned', 'house', 'put', 'order', 'greedy', 'cat', 'devoured', 'rest', 'fat', 'peace', 'everything', 'eaten', 'well', 'filled', 'fat', 'return', 'home', 'nighttime', 'mouse', 'immediately', 'asked', 'name', 'given', 'third', 'child', 'like', 'either', 'cat', 'name', 'allgone', 'allgone', 'cried', 'mouse', 'worrisome', 'name', 'never', 'seen', 'print', 'allgone', 'mean', 'shook', 'head', 'curled', 'lay', 'sleepfrom', 'time', 'forth', 'invited', 'cat', 'godfather', 'winter', 'come', 'longer', 'anything', 'found', 'outside', 'mouse', 'thought', 'stored', 'food', 'come', 'cat', 'go', 'pot', 'fat', 'stored', 'taste', 'good', 'yes', 'answered', 'cat', 'enjoy', 'much', 'enjoy', 'sticking', 'dainty', 'tongue', 'window', 'set', 'way', 'arrived', 'pot', 'fat', 'sure', 'still', 'place', 'empty', 'alas', 'mouse', 'see', 'happened', 'comes', 'light', 'true', 'friend', 'ate', 'everything', 'serving', 'godfather', 'first', 'top', 'half', 'done', 'quiet', 'cried', 'cat', 'word', 'eat', 'tooall', 'gone', 'already', 'poor', 'mouses', 'lips', 'scarcely', 'spoken', 'cat', 'sprang', 'seized', 'swallowed', 'see', 'way', 'world'])

# %% [markdown]
# ## Stemming

# %% [markdown]
# Stemming is the process of removing suffices, like "ed" or "ing".
#
# We will use another standard NLTK package, PorterStemmer, to do the stemming.

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
data['Text'][:5].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
# Out:
# 0    cat made acquaint mous much great love friends...
# 1    goat seven one fond ever mother children day g...
# 2    upon time ill thought like deathb send trusti ...
# 3    peasant driven cow fair sold seven thaler way ...
# 4    wonder musician quit alon forest thought manne...
# Name: Text, dtype: object

# %% [markdown]
# As we can see "wonderful" became "wonder", which could help an analysis, but "deathbed" became "deathb" which is less helpful.

# %% [markdown]
# ## Lemmatization

# %% [markdown]
# Lemmatization is often a more useful approach than stemming because it leverages an understanding of the word itself to convert the word back to its root word. However, this means lemmatization is less aggressive than stemming (probably a good thing).

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /users/egodat/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from textblob import Word
data['Text'] = data['Text'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
data['Text'].head()
# Out:
# 0    cat made acquaintance mouse much great love fr...
# 1    goat seven one fond ever mother child day go w...
# 2    upon time ill thought likely deathbed send tru...
# 3    peasant driven cow fair sold seven thalers way...
# 4    wonderful musician quite alone forest thought ...
# Name: Text, dtype: object

# %% [markdown]
# ## Visualizing Text with Wordclouds

# %% [markdown]
# Now, we are going to make a word cloud based on our data set.

# %%
import wordcloud

# %%
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt

stop_words = set(stop)
#stop_words.update(['see','saw','come','well','thought'])

# %% [markdown]
# If you want to update the stopwords after you see the wordcloud, type them into the empty list above and remove the # sign.

# %%
word = " ".join(data['Text'])
wordcloud = WordCloud(stopwords=stop_words, background_color="black").generate(word)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# The above code creates a wordcloud based off all the words (except for stop words) in all of the stories. While this can be fun, it may not be as interesting as a wordcloud for a single story. Let's compare:

# %%
for i in range(0, 3):
    word = data['Text'][i]
    wordcloud = WordCloud(stopwords=stop_words, background_color="white").generate(word)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# %% [markdown]
# # Advanced Text Mining Examples

# %% [markdown]
# In this section, we demonstrate more advanced techniques that can be used in text mining to extract more nuanced information and metrics than we can get with basic counting or wordclouds.

# %% [markdown]
# ## Load the Data

# %% [markdown]
# This is the same dataset as above but we are starting this section with a clean load of the data.

# %%
example_text_file = '../example_data/folktales.csv'

data = pd.read_csv(example_text_file)

data["Index"]=data.index
data.head()
# Out:
#    ID  ATU Code                 Author Country of Origin  \
# 0  17      15.0  Jacob & Wilhelm Grimm           Germany
# 1  44     123.0  Jacob & Wilhelm Grimm           Germany
# 2  54     516.0  Jacob & Wilhelm Grimm           Germany
# 3  64       NaN  Jacob & Wilhelm Grimm           Germany
# 4  74     151.0  Jacob & Wilhelm Grimm           Germany
#
#                              Original Title                        Source  \
# 0            Katze und Maus in Gesellschaft                           NaN
# 1  Der Wolf und die sieben jungen Geisslein                           NaN
# 2                        Der treue Johannes  The Blue Fairy Book (nr. 30)
# 3                           Der gute Handel                           NaN
# 4                 Der wunderliche Spielmann                           NaN
#
#                                                 Text  \
# 0  A cat had made the acquaintance of a mouse, an...
# 1  There was once an old goat who had seven littl...
# 2  ONCE upon a time there was an old king who was...
# 3  There was once a peasant who had driven his co...
# 4  There was once a wonderful musician, who went ...
#
#                                           Story Type  \
# 0       Stealing the Partner's Butter (ATU 15)\n\t\t
# 1   The Wolf and the Seven Young Kids (ATU 123)\n...
# 2               The Petrified Friend (ATU 516)\n\t\t
# 3                                                NaN
# 4     Music lessons for wild animals (ATU 151)\n\t\t
#
#                                Title               Translated  \
# 0       Cat and mouse in partnership            Margaret Hunt
# 1  The Wolf and the Seven Young Kids            Margaret Hunt
# 2                        Trusty John              Andrew Lang
# 3                   The good bargain            Margaret Hunt
# 4             The Wonderful Musician  Translated into English
#
#    Year Translated Year Written  Index
# 0           1884.0         1812      0
# 1           1884.0         1812      1
# 2           1889.0         1812      2
# 3           1884.0         1812      3
# 4              NaN         1812      4

# %% [markdown]
# ## Selected Cleaning

# %% [markdown]
# Here we have only decided to do a limited cleaning on the data to assist in our analysis.

# %% [markdown]
# ### Lowercase

# %%
data['Text'] = data['Text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
data['Text'].head()
# Out:
# 0    a cat had made the acquaintance of a mouse, an...
# 1    there was once an old goat who had seven littl...
# 2    once upon a time there was an old king who was...
# 3    there was once a peasant who had driven his co...
# 4    there was once a wonderful musician, who went ...
# Name: Text, dtype: object

# %% [markdown]
# ### Remove Punctuation

# %%
data['Text'] = data['Text'].str.replace('[^\w\s]','')
data['Text'].head()
# Out:
# 0    a cat had made the acquaintance of a mouse and...
# 1    there was once an old goat who had seven littl...
# 2    once upon a time there was an old king who was...
# 3    there was once a peasant who had driven his co...
# 4    there was once a wonderful musician who went q...
# Name: Text, dtype: object

# %% [markdown]
# ### Remove Stopwords

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
data['Text'] = data['Text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
data['Text'].head()
# Out:
# 0    cat made acquaintance mouse said much great lo...
# 1    old goat seven little ones fond ever mother ch...
# 2    upon time old king ill thought likely deathbed...
# 3    peasant driven cow fair sold seven thalers way...
# 4    wonderful musician went quite alone forest tho...
# Name: Text, dtype: object

# %% [markdown]
# ### Remove Frequent Words

# %%
freq = pd.Series(' '.join(data['Text']).split()).value_counts()[:10]
freq
# Out:
# said      9644
# one       4980
# came      3502
# little    3489
# went      3317
# could     3040
# would     3023
# king      2846
# old       2764
# man       2375
# dtype: int64

# %% [markdown]
# We now follow the same procedure with which we removed stopwords to remove the most frequent words.

# %%
#freq = list(freq.index)
#data['Text'] = data['Text'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
#data['Text'].head()

# %% [markdown]
# ## Lemmatization

# %% [markdown]
# Lemmatization is often a more useful approach than stemming because it leverages an understanding of the word itself to convert the word back to its root word. However, this means lemmatization is less aggressive than stemming (probably a good thing).

# %%
from textblob import Word
data['Text'] = data['Text'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
data['Text'].head()
# Out:
# 0    cat made acquaintance mouse said much great lo...
# 1    old goat seven little one fond ever mother chi...
# 2    upon time old king ill thought likely deathbed...
# 3    peasant driven cow fair sold seven thalers way...
# 4    wonderful musician went quite alone forest tho...
# Name: Text, dtype: object

# %% [markdown]
# At this point we have a several options for cleaning and structuring our text data. The next section will focus on more advanced ways to study text analytically.

# %% [markdown]
# ## Applying Algorithms to Text

# %% [markdown]
# This section focuses on more complex methods of analyzing textual data. We will continue to work with our same DataFrame.

# %% [markdown]
# ## N-grams

# %% [markdown]
# N-grams are combinations of multiple words as they appear in the text. The N refers to the number of words captured in the list. N-grams with N=1 are referred unigrams and are just a nested list of all the words in the text. Following a similar pattern, bigrams (N=2), trigrams (N=3), etc. can be used.
#
# N-grams allow you to capture the structure of the text which can be very useful. For instance, counting the number of bigrams where "said" was preceded by "he" vs "she" could give you an idea of the gender breakdown of speakers in a text. However, if you make your N-grams too long, you lose the ability to make comparisons.
#
# Another concern, especially in very large data sets, is that the memory storage of N-grams scales with N (bigrams are twice as large as unigrams, for example) and the time to process the N-grams can balloon dramatically as well.
#
# All that being said, we would suggest focusing on bigrams and trigrams as useful analysis tools.

# %%
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob

index = 3

lemmatizer = WordNetLemmatizer()
n_grams = TextBlob(data['Text'][index]).ngrams(2)

# %%
characters=[]
for i in ['wolf', 'cat', 'king', 'queen']:
     characters.append(lemmatizer.lemmatize(i))

# %%
for n in n_grams:
    if n[0] in characters:
        print(n)
# Out:
# ['king', 'sat']
# ['king', 'daughter']
# ['king', 'said']
# ['king', 'grew']
# ['king', 'replied']
# ['king', 'thou']
# ['king', 'daughter']
# ['king', 'let']
# ['king', 'jew']
# ['king', 'command']
# ['king', 'pull']
# ['king', 'could']
# ['king', 'cheated']
# ['king', 'run']
# ['king', 'heard']
# ['king', 'clothes']
# ['king', 'anger']
# ['king', 'reproached']
# ['king', 'king']
# ['king', 'heard']

# %%
from nltk import ngrams
from collections import Counter

ngram_counts = Counter(ngrams(data['Text'][index].split(), 2))
for n in ngram_counts.most_common(10):
    print(n)
# Out:
# (('aik', 'aik'), 15)
# (('wow', 'wow'), 7)
# (('three', 'day'), 7)
# (('seven', 'thalers'), 4)
# (('money', 'pocket'), 4)
# (('said', 'peasant'), 4)
# (('lord', 'king'), 4)
# (('thou', 'art'), 3)
# (('answered', 'peasant'), 3)
# (('said', 'thou'), 3)

# %% [markdown]
# ## Term Frequency

# %% [markdown]
# Term Frequency is a measure of how often a term appears in a document. There are different ways to define this but the simplest is a raw count of the number of times each term appears.
#
# There are other ways of defining this including a true term frequency and a log scaled definition. All three have been implemented below but the default will the raw count definition, as it matches with the remainder of the definitions in this tutorial.
#
# |Definition|Formula|
# |---|---|
# |Raw Count|$$f_{t,d}$$|
# |Term Frequency|$$\frac{f_{t,d}}{\sum_{t'\in d}f_{t',d}}$$|
# |Log Scaled|$$\log(1+f_{t,d})$$|

# %%
## Raw Count Definition
tf1 = (data['Text'][0:5]).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()

## Term Frequency Definition
#tf1 = (data['Story'][0:5]).apply(lambda x: (pd.value_counts(x.split(" ")))/len(x.split(" "))).sum(axis = 0).reset_index() 

## Log Scaled Definition
#tf1 = (data['Story'][0:10]).apply(lambda x: 1.0+np.log(pd.value_counts(x.split(" ")))).sum(axis = 0).reset_index() 

tf1.columns = ['words','tf']
tf1.sort_values(by='tf', ascending=False)[:10]
# Out:
#          words    tf
# 2         said  85.0
# 440       king  63.0
# 441       john  39.0
# 442     trusty  37.0
# 8          one  36.0
# 1078  musician  31.0
# 883       thou  31.0
# 26       cried  27.0
# 255       wolf  27.0
# 28        went  27.0

# %% [markdown]
# ## Inverse Document Frequency

# %% [markdown]
# Inverse Document Frequency is a measure of how common or rare a term is across multiple documents. That gives a measure of how much weight that term carries.
#
# For a more concrete analogy of this, imagine a room full of NBA players; here a 7 foot tall person wouldn't be all that shocking. However if you have a room full of kindergarten students, a 7 foot tall person would be a huge surprise.
#
# The simplest and standard definition of Inverse Document Frequency is to take the logarithm of the ratio of the number of documents containing a term to the total number of documents.
#
# $$-\log\frac{n_t}{N} = \log\frac{N}{n_t}$$

# %%
for i,word in enumerate(tf1['words']):
    tf1.loc[i, 'idf'] = np.log(data.shape[0]/(len(data[data['Text'].str.contains(word)])))

tf1[:10]
# Out:
#        words    tf       idf
# 0        cat  21.0  1.162270
# 1      mouse  20.0  2.591737
# 2       said  85.0  0.255887
# 3        fat   9.0  0.847665
# 4       name  10.0  1.262168
# 5        pot   7.0  1.449952
# 6       good  19.0  0.584708
# 7      asked  12.0  0.797529
# 8        one  36.0  0.192505
# 9  godfather   6.0  4.614020

# %% [markdown]
# ## Term Frequency – Inverse Document Frequency ([TF-IDF](https://en.wikipedia.org/wiki/Tf%E2%80%93idf))

# %% [markdown]
# Term Frequency – Inverse Document Frequency (TF-IDF) is a composite measure of both Term Frequency and Inverse Document Frequency.
#
# From [Wikipedia](https://en.wikipedia.org/wiki/Tf%E2%80%93idf):
# "A high weight in TF–IDF is reached by a high term frequency (in the given document) and a low document frequency of the term in the whole collection of documents; the weights hence tend to filter out common terms"
#
# More concisely, a high TD-IDF says that a word is very important in the documents in which it appears.
#
# There are a few weighting schemes for TF-IDF. Here we use scheme (1).
#
# |Weighting Scheme|Document Term Weight|
# |---|---|
# |(1)|$$f_{t,d}\cdot\log\frac{N}{n_t}$$|
# |(2)|$$1+\log(f_{t,d})$$|
# |(3)|$$(1+\log(f_{t,d}))\cdot\log\frac{N}{n_t}$$|

# %%
tf1['tfidf'] = tf1['tf'] * tf1['idf']
tf1.sort_values(by='tfidf', ascending=False)[:10]
# Out:
#          words    tf       idf       tfidf
# 441       john  39.0  4.038656  157.507571
# 442     trusty  37.0  4.172187  154.370921
# 884        aik  20.0  6.811244  136.224888
# 1078  musician  31.0  4.038656  125.198325
# 882    peasant  25.0  2.548565   63.714113
# 255       wolf  27.0  2.278645   61.523412
# 888        wow  12.0  4.731803   56.781634
# 1        mouse  20.0  2.591737   51.834733
# 885        jew  16.0  2.750801   44.012822
# 257        kid  10.0  3.920873   39.208726

# %% [markdown]
# It is worth noting that the *sklearn* library has the ability to directly calculate a TD-IDF matrix.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features=1000, lowercase=True, analyzer='word',
 stop_words= 'english',ngram_range=(1,1))
data_vect = tfidf.fit_transform(data['Text'])

data_vect
# Out:
# <908x1000 sparse matrix of type '<class 'numpy.float64'>'
# 	with 120389 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Similarity

# %%
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import warnings
warnings.filterwarnings("ignore", category=FutureWarning) # This suppresses a warning from scikit learn that they are going to update their code

# %% [markdown]
# One thing we can look at is how similar two texts are. This has a practical use when looking for plagiarism, but can also be used to compare author's styles. To do this there are a few ways we can measure similarity.

# %% [markdown]
# First we need to set up our two sets of texts. Here we have the ability to choose the size of our sets and whether we want the first n texts from our full data set or just a random sample. Keep in mind that if you want to use two dissimilar sets, you won't have a control value (something x itself).

# %%
size=10

# %%
## First n by First n
set1 = data[["Index",'Text','Title']][:size]
set2 = data[["Index",'Text','Title']][:size]

## Random X Itself
#set1 = data[["Index",'Story','Title']].sample(size)
#set2 = set1

## First n by Random
#set1 = data[["Index",'Story','Title']][:size]
#set2 = data[["Index",'Story','Title']].sample(size)

## Random X Random
#set1 = data[["Index",'Story','Title']].sample(size)
#set2 = data[["Index",'Story','Title']].sample(size)

# %%
#To let us do a "cross join": Every row in one gets matched to all rows in the other
set1['key']=1 
set2['key']=1

similarity = pd.merge(set1, set2, on ='key', suffixes=('_1', '_2')).drop("key", 1)

# %% [markdown]
# ### Jaccard Similarity

# %% [markdown]
# The first is using a metric called the [Jaccard Index](https://en.wikipedia.org/wiki/Jaccard_index). This is just taking the intersection of two sets of things (in our case, words or n-grams) and dividing it by the union of those sets. This gives us a metric for understanding how the word usage compares but doesn't account for repeated words since the union and intersections just take unique words. One advantage though is that we can easily extend the single word similarity to compare bi-grams and other n-grams if we want to examine phrase usage.
#
# $$S_{J}(A,B)=\frac{A \cap B}{A \cup B}$$

# %%
def jaccard(row, n=1):
    
    old=row['Text_1']
    new=row['Text_2']
    
    old_n_grams = [tuple(el) for el in TextBlob(old).ngrams(n)]
    new_n_grams = [tuple(el) for el in TextBlob(new).ngrams(n)]
        
    union = list(set(old_n_grams) | set(new_n_grams))
    intersection = list(set(old_n_grams) & set(new_n_grams))
    
    lu = len(union)
    li = len(intersection)
    
    return (li/lu,li,lu)

# %%
for i in [1,2]: # Add values to the list for the n-gram you're interested in
    similarity['Jaccard_Index_for_{}_grams'.format(i)]=similarity.apply(lambda x: jaccard(x,i)[0],axis=1)

# %%
similarity['Intersection']=similarity.apply(lambda x: jaccard(x)[1],axis=1)

# %%
similarity['Union']=similarity.apply(lambda x: jaccard(x)[2],axis=1)

# %%
similarity.head()
# Out:
#    Index_1                                             Text_1  \
# 0        0  cat made acquaintance mouse said much great lo...
# 1        0  cat made acquaintance mouse said much great lo...
# 2        0  cat made acquaintance mouse said much great lo...
# 3        0  cat made acquaintance mouse said much great lo...
# 4        0  cat made acquaintance mouse said much great lo...
#
#                         Title_1  Index_2  \
# 0  Cat and mouse in partnership        0
# 1  Cat and mouse in partnership        1
# 2  Cat and mouse in partnership        2
# 3  Cat and mouse in partnership        3
# 4  Cat and mouse in partnership        4
#
#                                               Text_2  \
# 0  cat made acquaintance mouse said much great lo...
# 1  old goat seven little one fond ever mother chi...
# 2  upon time old king ill thought likely deathbed...
# 3  peasant driven cow fair sold seven thalers way...
# 4  wonderful musician went quite alone forest tho...
#
#                              Title_2  Jaccard_Index_for_1_grams  \
# 0       Cat and mouse in partnership                   1.000000
# 1  The Wolf and the Seven Young Kids                   0.149660
# 2                        Trusty John                   0.134387
# 3                   The good bargain                   0.155140
# 4             The Wonderful Musician                   0.109091
#
#    Jaccard_Index_for_2_grams  Intersection  Union
# 0                   1.000000           256    256
# 1                   0.000000            66    441
# 2                   0.002424           102    759
# 3                   0.005338            83    535
# 4                   0.002463            48    440

# %% [markdown]
# ### Cosine Similarity

# %% [markdown]
# The second metric we can use is [Cosine Similarity](https://en.wikipedia.org/wiki/Cosine_similarity), however there is a catch here. Cosine similarity requires a vector for each word so we make a choice here to use term frequency. You could choose something else, inverse document frequency or tf-idf would both be good choices. Cosine similarity with a term frequency vector gives us something very similar to the Jaccard Index but accounts for word repetition. This makes it better for tracking word importance between two texts.
#
# $$S_{C}(v_1,v_2)=cos(\theta)=\frac{v_1\cdot v_2}{||v_1||\times||v_2||}$$

# %%
def get_cosine_sim(str1,str2): 
    vectors = [t for t in get_vectors([str1,str2])]
    return cosine_similarity(vectors)
    
def get_vectors(slist):
    text = [t for t in slist]
    vectorizer = CountVectorizer(text)
    vectorizer.fit(text)
    return vectorizer.transform(text).toarray()

def cosine(row):
    
    old=row['Text_1']
    new=row['Text_2']
    
    return get_cosine_sim(old,new)[0,1]

# %%
similarity['Cosine_Similarity']=similarity.apply(lambda x: cosine(x),axis=1)

# %%
similarity.head()
# Out:
#    Index_1                                             Text_1  \
# 0        0  cat made acquaintance mouse said much great lo...
# 1        0  cat made acquaintance mouse said much great lo...
# 2        0  cat made acquaintance mouse said much great lo...
# 3        0  cat made acquaintance mouse said much great lo...
# 4        0  cat made acquaintance mouse said much great lo...
#
#                         Title_1  Index_2  \
# 0  Cat and mouse in partnership        0
# 1  Cat and mouse in partnership        1
# 2  Cat and mouse in partnership        2
# 3  Cat and mouse in partnership        3
# 4  Cat and mouse in partnership        4
#
#                                               Text_2  \
# 0  cat made acquaintance mouse said much great lo...
# 1  old goat seven little one fond ever mother chi...
# 2  upon time old king ill thought likely deathbed...
# 3  peasant driven cow fair sold seven thalers way...
# 4  wonderful musician went quite alone forest tho...
#
#                              Title_2  Jaccard_Index_for_1_grams  \
# 0       Cat and mouse in partnership                   1.000000
# 1  The Wolf and the Seven Young Kids                   0.149660
# 2                        Trusty John                   0.134387
# 3                   The good bargain                   0.155140
# 4             The Wonderful Musician                   0.109091
#
#    Jaccard_Index_for_2_grams  Intersection  Union  Cosine_Similarity
# 0                   1.000000           256    256           1.000000
# 1                   0.000000            66    441           0.204954
# 2                   0.002424           102    759           0.219593
# 3                   0.005338            83    535           0.260824
# 4                   0.002463            48    440           0.210696

# %% [markdown]
# ### Visualize Similarity

# %%
metric = 'Cosine_Similarity'
#metric = 'Jaccard_Index_for_1_grams'

# %%
import numpy as np 
import matplotlib.pyplot as plt

index = list(similarity['Index_1'].unique())
columns = list(similarity['Index_2'].unique())
df = pd.DataFrame(0, index=index, columns=columns)

for i in df.index:
    sub = similarity[(similarity['Index_1']==i)]
    for col in df.columns:
        df.loc[i,col]=sub[sub['Index_2']==col][metric].iloc[0]
        
plt.pcolor(df)
plt.yticks(np.arange(0.5, len(df.index), 1), df.index)
plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns)
plt.show()

# %%
similarity[['Title_1','Index_1','Title_2','Index_2',metric]].sort_values(by=metric,ascending=False)
# Out:
#                               Title_1  Index_1  \
# 44             The Wonderful Musician        4
# 99                    The white snake        9
# 11  The Wolf and the Seven Young Kids        1
# 88             The three snake-leaves        8
# 55                The twelve brothers        5
# ..                                ...      ...
# 10  The Wolf and the Seven Young Kids        1
# 46             The Wonderful Musician        4
# 64                           Rapunzel        6
# 13  The Wolf and the Seven Young Kids        1
# 31                   The good bargain        3
#
#                               Title_2  Index_2  Cosine_Similarity
# 44             The Wonderful Musician        4           1.000000
# 99                    The white snake        9           1.000000
# 11  The Wolf and the Seven Young Kids        1           1.000000
# 88             The three snake-leaves        8           1.000000
# 55                The twelve brothers        5           1.000000
# ..                                ...      ...                ...
# 10       Cat and mouse in partnership        0           0.204954
# 46                           Rapunzel        6           0.200260
# 64             The Wonderful Musician        4           0.200260
# 13                   The good bargain        3           0.156699
# 31  The Wolf and the Seven Young Kids        1           0.156699
#
# [100 rows x 5 columns]

# %% [markdown]
# ## [Bag of Words](https://en.wikipedia.org/wiki/Bag-of-words_model)

# %% [markdown]
# [Bag of Words](https://en.wikipedia.org/wiki/Bag-of-words_model) a way to represent text based on the idea that similar texts will contain similar vocabulary. There is a lot to this model and we provide merely a simple implementation of it here.

# %%
from sklearn.feature_extraction.text import CountVectorizer
bow = CountVectorizer(max_features=1000, lowercase=True, ngram_range=(1,1),analyzer = "word")
data_bow = bow.fit_transform(data['Text'])
data_bow
# Out:
# <908x1000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 140525 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# Sentiment is a way of measuring the overall positivity or negativity in a given text.
#
# To do this we will use the built in sentiment function in the *TextBlob* package. This function will return the polarity and subjectivity scores for each data chunk.

# %%
data['Text'][:5].apply(lambda x: TextBlob(x).sentiment)
# Out:
# 0      (0.20047881411517773, 0.4731541606541606)
# 1     (-0.03739606953892669, 0.4066515495086924)
# 2      (0.20665529269032465, 0.5145875037913257)
# 3      (0.11377134101853201, 0.5322474342137266)
# 4    (0.027741815476190472, 0.44031994047619044)
# Name: Text, dtype: object

# %% [markdown]
# Focusing on the polarity score, we are able to see the overall sentiment of each data chunk. The closer to 1 the more positive and the closer to -1 the more negative.

# %%
data['sentiment'] = data['Text'].apply(lambda x: TextBlob(x).sentiment[0] )
data[['Text','sentiment']].head()
# Out:
#                                                 Text  sentiment
# 0  cat made acquaintance mouse said much great lo...   0.200479
# 1  old goat seven little one fond ever mother chi...  -0.037396
# 2  upon time old king ill thought likely deathbed...   0.206655
# 3  peasant driven cow fair sold seven thalers way...   0.113771
# 4  wonderful musician went quite alone forest tho...   0.027742

# %% [markdown]
# Here we have textted the sentiment scores for the first 10 chunks.
#
# Notice they tend to be positive but not exceedingly so.

# %%
plot_1 = data[['sentiment']][:10].plot(kind='bar',)

# %% [markdown]
# Now we have sorted and textted all of the sentiment scores for the chunks in our database.
#
# We can clearly see that most of the text data is positive but not overwhelmingly so (as seen by the long tail of the distribution). However, the parts that are negative tend to be more polarized than the positive ones (a shorter tail and sharper peak).

# %%
plot_2 = data[['sentiment']].sort_values(by='sentiment', ascending=False).plot(kind='bar')

# %% [markdown]
# ## Using TF-IDF and Machine Learning

# %% [markdown]
# This is significantly more advanced than the rest of the tutorial. This takes the TF-IDF matrix and applies a [k-means clustering algorithm](https://en.wikipedia.org/wiki/K-means_clustering). This groups the texts into clusters of similar terms from the TF-IDF matrix. This algorithm randomly seeds X "means", the values are then clustered into the nearest mean. The centroid of the values in each cluster then becomes the new mean and the process repeats until a convergence is reached.

# %%
import matplotlib.pyplot as plt
import matplotlib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

groups = 30

num_clusters = groups
num_seeds = groups
max_iterations = 300

cmap = matplotlib.cm.get_cmap("nipy_spectral", groups) # Builds a discrete color mapping using a built in matplotlib color map

c = {}
for i in range(cmap.N): # Converts our discrete map into Hex Values
    rgba = cmap(i)
    c.update({i:matplotlib.colors.rgb2hex(rgba)})

labels_color_map=c

pca_num_components = 2
tsne_num_components = 2

# calculate tf-idf of texts
tfidf = TfidfVectorizer(max_features=1000, lowercase=True, analyzer='word',stop_words= 'english',ngram_range=(1,1))
tf_idf_matrix = tfidf.fit_transform(data['Text'])

# create k-means model with custom config
clustering_model = KMeans(
    n_clusters=num_clusters,
    max_iter=max_iterations,
    precompute_distances="auto",
    n_jobs=-1
)

labels = clustering_model.fit_predict(tf_idf_matrix)
#print(labels)

X = tf_idf_matrix.todense()

# ----------------------------------------------------------------------------------------------------------------------

reduced_data = PCA(n_components=pca_num_components).fit_transform(X)
# print(reduced_data)

import matplotlib.patches as mpatches
legendlist=[mpatches.Patch(color=labels_color_map[key],label=str(key))for key in labels_color_map.keys()]

fig, ax = plt.subplots()
for index, instance in enumerate(reduced_data):
    #print(instance, index, labels[index])
    pca_comp_1, pca_comp_2 = reduced_data[index]
    color = labels_color_map[labels[index]]
    ax.scatter(pca_comp_1, pca_comp_2, c=color)
plt.legend(handles=legendlist)
plt.show()

# %%
title_groups = np.transpose([labels,data['Title'],data['Author'],data['Index']])

# %% [markdown]
# These are the titles of the texts in each cluster. Keep in mind that each time you run the algorithm, the randomness in generating the initial means will result in different clusters.

# %%
for i in range(len(title_groups)):
    data.loc[i,'Group'] = title_groups[i][0]

# %% [markdown]
# This is how the groups break down by number of texts in each.

# %%
g_counts = data['Group'].value_counts()
ss = min(g_counts)
g_counts
# Out:
# 18.0    156
# 12.0     76
# 28.0     65
# 20.0     61
# 26.0     49
# 5.0      41
# 0.0      39
# 29.0     38
# 23.0     33
# 8.0      33
# 6.0      29
# 14.0     28
# 11.0     26
# 16.0     25
# 10.0     20
# 9.0      18
# 3.0      17
# 4.0      17
# 7.0      17
# 15.0     14
# 24.0     13
# 19.0     12
# 25.0     12
# 22.0     11
# 2.0      11
# 21.0     11
# 17.0     11
# 13.0      9
# 1.0       8
# 27.0      8
# Name: Group, dtype: int64

# %% [markdown]
# Here we can look at a sample of the titles in a particular group and the TF-IDF data for that group.

# %%
grp=13
data[data['Group']==grp]['Title'].sample(ss)
# Out:
# 310      The King of the Sea and Vassilissa the Wise
# 324                     Tsarevich Ivan and Grey Wolf
# 304                                    Marya Morevna
# 467                                The Princess Frog
# 299                                  Right and Wrong
# 301                               The Three Kingdoms
# 300                  Prince Ivan and Princess Martha
# 305    King Ivan and Bely, the Warrior of the Plains
# Name: Title, dtype: object

# %%
group_ids = list(data[data['Group']==grp]['Index'])
group_tfidf = data[data['Index'].isin(group_ids)]['Text'].apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()

group_tfidf.columns = ['words','tf']
group_tfidf.sort_values(by='tf', ascending=False)[:10]

for i,word in enumerate(group_tfidf['words']):
    group_tfidf.loc[i, 'idf'] = np.log(data.shape[0]/(len(data[data['Text'].str.contains(word)])))

group_tfidf['tfidf'] = group_tfidf['tf'] * group_tfidf['idf']
group_tfidf.sort_values(by='tfidf', ascending=False)[:10]
# Out:
#           words     tf       idf        tfidf
# 3          ivan  416.0  3.978031  1654.860910
# 208      prince  325.0  1.517940   493.330355
# 1078      marya   36.0  6.811244   245.204798
# 1920  tsarevich   39.0  6.118097   238.605791
# 597       elena   45.0  5.201806   234.081291
# 1079    morevna   30.0  6.811244   204.337331
# 1352       bely   29.0  6.811244   197.526087
# 979     warrior   40.0  4.103194   164.127767
# 1923       tsar   30.0  5.424950   162.748501
# 1080   koshchei   23.0  6.811244   156.658621

# %%
text_index = 0
pd.Series(' '.join(data[data['Index']==text_index]['Text']).split()).value_counts()[:10]
# Out:
# cat          21
# mouse        20
# said         15
# fat           9
# name          8
# pot           7
# good          7
# asked         7
# one           6
# godfather     6
# dtype: int64

# %% [markdown]
# Here we can look at all the groups along with the authors and the index for each story.

# %%
for i in range(groups):
    print("")
    print("#### {} ###".format(i))
    print("")
    for el in title_groups:
        if el[0]==i:
            print("{} --- {} --- #{}".format(el[1],str(el[2]).strip(), el[3]))
# Out:
# #### 0 ###
#
# The golden bird --- Jacob & Wilhelm Grimm --- #44
# The wolf and the man --- Jacob & Wilhelm Grimm --- #58
# The wolf and the fox --- Jacob & Wilhelm Grimm --- #59
# Gossip wolf and the fox --- Jacob & Wilhelm Grimm --- #60
# The fox and the cat --- Jacob & Wilhelm Grimm --- #61
# The fox and the geese --- Jacob & Wilhelm Grimm --- #69
# The Cat, the Rooster and the Fox --- Alexander Afanasyev --- #290
# The Animals in the Pit --- Alexander Afanasyev --- #292
# The Fox and the Crane --- Alexander Afanasyev --- #295
# The Fox as Herdsman --- Asbjørnsen & Moe --- #334
# Bear and Bruin --- Asbjørnsen & Moe --- #347
# Well Done and Ill Paid --- Asbjørnsen & Moe --- #362
# Nanny Who Wouldn't Go Home to Supper --- Asbjørnsen & Moe --- #418
# Snegurushka and the Fox --- Alexander Afanasyev --- #462
# Liza the Fox and Catafay the Cat --- Alexander Afanasyev --- #464
# The Eagle and the Fox  --- Aesop --- #486
# Acheria, the Fox --- Wentworth Webster --- #496
# The Fox and the Grapes --- Aesop --- #507
# The Bear and the Fox --- Aesop --- #524
# The Fox and the Goat --- Aesop --- #528
# The Fox Who Had Lost His Tail --- Aesop --- #542
# The Wild Boar and the Fox --- Aesop --- #588
# The Fox and the Woodcutter --- Aesop --- #591
# The Fox and the Leopard --- Aesop --- #602
# The Crab and the Fox --- Aesop --- #613
# The Hares and the Foxes --- Aesop --- #617
# The Jackdaw and the Fox --- Aesop --- #658
# The Fox and the Bramble --- Aesop --- #670
# The Ass in the Lion's Skin --- Aesop --- #691
# The Wolf and Fox, with the Ape for Judge --- Phaedrus --- #716
# The Fox and the Stork --- Phaedrus --- #732
# The Fox and Eagle --- Phaedrus --- #734
# The Fox and the Tragic Mask --- Phaedrus --- #738
# The Fox and the Grapes --- Phaedrus --- #769
# The Fox and the Goat --- Phaedrus --- #774
# The Raven and the Fox  --- Ivan Krylov --- #786
# The Wolf and the Fox In the Well --- Jean de La Fontaine --- #833
# The Fox and the Young Turkeys --- Jean de La Fontaine --- #838
# The Willow-Wren and the Bear --- Jacob & Wilhelm Grimm --- #906
#
# #### 1 ###
#
# Clever Hans --- Jacob & Wilhelm Grimm --- #24
# Clever Else --- Jacob & Wilhelm Grimm --- #26
# Hans in luck --- Jacob & Wilhelm Grimm --- #66
# Hans married --- Jacob & Wilhelm Grimm --- #67
# The griffin --- Jacob & Wilhelm Grimm --- #121
# Strong Hans --- Jacob & Wilhelm Grimm --- #122
# Clumsy Hans --- H.C. Andersen --- #219
# The cripple --- H.C. Andersen --- #283
#
# #### 2 ###
#
# The tailor in heaven --- Jacob & Wilhelm Grimm --- #27
# Brother Lustig --- Jacob & Wilhelm Grimm --- #64
# Gambling Hansel --- Jacob & Wilhelm Grimm --- #65
# The old man made young again --- Jacob & Wilhelm Grimm --- #111
# The peasant in heaven --- Jacob & Wilhelm Grimm --- #123
# The Tale of Ruff Ruffson, Son of Bristle --- Alexander Afanasyev --- #294
# Rich Peter the Pedlar --- Asbjørnsen & Moe --- #354
# Gertrude's Bird --- Asbjørnsen & Moe --- #355
# Lord Peter  --- Asbjørnsen & Moe --- #366
# Boots and His Brothers --- Asbjørnsen & Moe --- #370
# Big Peter and Little Peter  --- Asbjørnsen & Moe --- #371
#
# #### 3 ###
#
# The drop of water --- H.C. Andersen --- #193
# The flax --- H.C. Andersen --- #197
# A cheerful temper --- H.C. Andersen --- #207
# The last pearl --- H.C. Andersen --- #215
# The Jewish girl --- H.C. Andersen --- #222
# The A-B-C book --- H.C. Andersen --- #230
# Two brothers --- H.C. Andersen --- #238
# What the whole family said --- H.C. Andersen --- #274
# Dance, dance, doll of mine! --- H.C. Andersen --- #278
# Reynard And Chanticleer --- Asbjørnsen & Moe --- #401
# The Boy Hunting Locusts --- Aesop --- #513
# The Pomegranate, Apple-Tree, and Bramble --- Aesop --- #521
# The Ape's Head --- Phaedrus --- #754
# The Brother and Sister --- Phaedrus --- #758
# The Two Bald Men --- Phaedrus --- #779
# Democritus and the People of Abdera --- Jean de La Fontaine --- #822
# The Gods Wishing To Instruct a Son of Jupiter --- Jean de La Fontaine --- #831
#
# #### 4 ###
#
# A picture from the ramparts --- H.C. Andersen --- #187
# The Phoenix bird --- H.C. Andersen --- #198
# The swan's nest --- H.C. Andersen --- #202
# On judgment day --- H.C. Andersen --- #205
# The thorny road of honor --- H.C. Andersen --- #221
# The bird of folklore --- H.C. Andersen --- #255
# The Vain Jackdaw --- Aesop --- #540
# The Swallow, the Serpent, and the Court of Justice --- Aesop --- #557
# The Kites and the Swans --- Aesop --- #615
# The Peacock and the Crane --- Aesop --- #621
# The Fly and the Mule --- Phaedrus --- #756
# The Sacrilegious Thief --- Phaedrus --- #761
# The He-goats and She-goats --- Phaedrus --- #763
# Opportunity --- Phaedrus --- #780
# The Swan, The Pike and the Crayfish  --- Ivan Krylov --- #787
# The Cobbler and the Financier --- Jean de La Fontaine --- #816
# The Goose that Laid the Golden Egg --- Avianus --- #844
#
# #### 5 ###
#
# Hansel and Gretel --- Jacob & Wilhelm Grimm --- #7
# Cinderella --- Jacob & Wilhelm Grimm --- #13
# Mother Hulda --- Jacob & Wilhelm Grimm --- #16
# The seven ravens --- Jacob & Wilhelm Grimm --- #17
# The almond tree --- Jacob & Wilhelm Grimm --- #35
# Roland --- Jacob & Wilhelm Grimm --- #43
# Old Hildebrand --- Jacob & Wilhelm Grimm --- #77
# Sweet Porridge --- Jacob & Wilhelm Grimm --- #83
# Fair Katrinelje and Pif-Paf-Poltrie --- Jacob & Wilhelm Grimm --- #97
# Odds and ends --- Jacob & Wilhelm Grimm --- #114
# Snow-White and Rose-Red --- Jacob & Wilhelm Grimm --- #118
# Five peas from a pod --- H.C. Andersen --- #212
# She was good for nothing --- H.C. Andersen --- #213
# The girl who trod on the loaf --- H.C. Andersen --- #235
# The bond of friendship --- H.C. Andersen --- #249
# Baba Yaga --- Alexander Afanasyev --- #288
# The Swan-Geese --- Alexander Afanasyev --- #298
# Fenist the Falcon --- Alexander Afanasyev --- #311
# The Two Step-Sisters --- Asbjørnsen & Moe --- #341
# Thumbikin --- Asbjørnsen & Moe --- #375
# The Sweetheart In The Wood --- Asbjørnsen & Moe --- #387
# The Cock Who Fell into the Brewing Vat --- Asbjørnsen & Moe --- #419
# The Fairies --- Charles Perrault --- #426
# Vardiello --- Giambattista Basile --- #431
# The Maiden and the Beast --- Consiglieri Pedroso --- #476
# Little Snow White --- Jacob & Wilhelm Grimm --- #477
# The Young Slave --- Giambattista Basile --- #485
# The Hearth-Cat --- Consiglieri Pedroso --- #487
# The Frog and the Ox --- Aesop --- #489
# Basa Jauna, the Wild Man --- Wentworth Webster --- #497
# The Mole and His Mother --- Aesop --- #519
# The Crab and Its Mother --- Aesop --- #555
# The Thief and His Mother --- Aesop --- #558
# The Sick Kite --- Aesop --- #571
# The Monkeys and Their Mother --- Aesop --- #603
# The Cobbler and His Three Daughters --- Wentworth Webster --- #793
# The Enchanted Shoes --- Adolfo Coelho --- #795
# Toads and Diamonds --- Charles Perrault --- #878
# The Rooster and the Hyena --- Charles Bailleul --- #885
# The story of the selfish husband --- Dorothea Lehmann --- #900
# The Story of the Steward --- Clement M. Doke --- #902
#
# #### 6 ###
#
# The little mermaid --- H.C. Andersen --- #156
# The garden of paradise --- H.C. Andersen --- #163
# The wicked prince --- H.C. Andersen --- #166
# Alyosha Popovich --- Alexander Afanasyev --- #287
# The White Duck --- Alexander Afanasyev --- #289
# East o' the Sun and West o' the Moon --- Asbjørnsen & Moe --- #328
# Hacon Grizzlebeard --- Asbjørnsen & Moe --- #330
# The Giant Who Had No Heart in His Body --- Asbjørnsen & Moe --- #333
# The Mastermaid --- Asbjørnsen & Moe --- #335
# The Lassie and Her Godmother --- Asbjørnsen & Moe --- #351
# The Three Aunts --- Asbjørnsen & Moe --- #352
# Katie Woodencloak --- Asbjørnsen & Moe --- #374
# Little Annie the Goose-Girl --- Asbjørnsen & Moe --- #382
# The Myrtle --- Giambattista Basile --- #421
# Violet --- Giambattista Basile --- #440
# The She-Bear --- Giambattista Basile --- #442
# The Dove --- Giambattista Basile --- #443
# Nennillo and Nennella --- Giambattista Basile --- #455
# The Three Citrons --- Giambattista Basile --- #456
# The Morning Star And The Evening Star --- Petre Ispirescu --- #457
# Youth Without Age And Life Without Death --- Petre Ispirescu --- #458
# Asmund and Signy --- Jón Árnason --- #706
# Gesture of Death --- Jean Cocteau --- #865
# Prince Hyacinth and the Dear Little Princess --- Jeanne-Marie Leprince de Beaumont --- #867
# East of the Sun and West of the Moon --- Asbjørnsen & Moe --- #868
# The Master-Maid --- Asbjørnsen & Moe --- #871
# The White Cat --- Madame d'Aulnoy --- #872
# The Golden Branch --- Madame d'Aulnoy --- #884
# The gardiner and Death --- Jean Cocteau --- #905
#
# #### 7 ###
#
# The Wonderful Musician --- Jacob & Wilhelm Grimm --- #4
# Knoist and his three sons --- Jacob & Wilhelm Grimm --- #104
# The hare and the hedgehog --- Jacob & Wilhelm Grimm --- #135
# The races --- H.C. Andersen --- #232
# Shabarsha --- Alexander Afanasyev --- #303
# The Hare And The Heiress --- Asbjørnsen & Moe --- #406
# Osborn's Pipe --- Asbjørnsen & Moe --- #416
# Fox, Hare and Cock --- Alexander Afanasyev --- #466
# The Kingdom of the Lion --- Aesop --- #514
# The Lion and the Hare --- Aesop --- #598
# The Dog and the Hare --- Aesop --- #620
# The Hares and the Frogs --- Aesop --- #679
# The Wonderful Musician --- Jacob & Wilhelm Grimm --- #694
# The Hare and the Partridge --- Jean de La Fontaine --- #804
# The Gardener and his Landlord --- Jean de La Fontaine --- #805
# The Nyamatsanes --- E. Jacottet --- #881
# How Hare Scared Elephant  --- Edwin W. Smith --- #895
#
# #### 8 ###
#
# Baba-Yaga and Puny --- Alexander Afanasyev --- #297
# Don't Listen, If You Don't Like --- Alexander Afanasyev --- #322
# Boots Who Ate a Match With the Troll --- Asbjørnsen & Moe --- #329
# The Cat on the Dovrefell --- Asbjørnsen & Moe --- #336
# Princess on the Glass Hill --- Asbjørnsen & Moe --- #337
# How One Went Out to Woo --- Asbjørnsen & Moe --- #338
# Taming the Shrew --- Asbjørnsen & Moe --- #343
# The Blue Belt --- Asbjørnsen & Moe --- #346
# The Three Princesses of Whiteland --- Asbjørnsen & Moe --- #350
# Boots and the Troll --- Asbjørnsen & Moe --- #356
# The Lad Who Went to the North Wind --- Asbjørnsen & Moe --- #358
# The Best Wish --- Asbjørnsen & Moe --- #360
# Dapplegrim --- Asbjørnsen & Moe --- #364
# The Seven Foals --- Asbjørnsen & Moe --- #367
# The Widow's Son --- Asbjørnsen & Moe --- #368
# Bushy Bride --- Asbjørnsen & Moe --- #369
# Doll i' the Grass --- Asbjørnsen & Moe --- #376
# The Lad and the Deil --- Asbjørnsen & Moe --- #377
# Soria Moria Castle --- Asbjørnsen & Moe --- #380
# Tom Totherhouse --- Asbjørnsen & Moe --- #381
# The Golden Palace That Hung In The Air --- Asbjørnsen & Moe --- #386
# The Trolls In Hedale Wood --- Asbjørnsen & Moe --- #388
# Boots And His Crew --- Asbjørnsen & Moe --- #390
# Master Tobacco --- Asbjørnsen & Moe --- #392
# The Companion --- Asbjørnsen & Moe --- #399
# The Honest Penny --- Asbjørnsen & Moe --- #402
# Our Parish Clerk --- Asbjørnsen & Moe --- #405
# The Three Years Without Wages --- Asbjørnsen & Moe --- #407
# Silly Matt --- Asbjørnsen & Moe --- #408
# Little Freddy With His Fiddle --- Asbjørnsen & Moe --- #410
# The Squire's Bride --- Asbjørnsen & Moe --- #415
# The Storehouse Key in the Disdaff --- Asbjørnsen & Moe --- #417
# The Booby --- Giambattista Basile --- #446
#
# #### 9 ###
#
# The poor boy in the grave --- Jacob & Wilhelm Grimm --- #133
# Little Claus and big Claus --- H.C. Andersen --- #150
# Goosey Grizzel --- Asbjørnsen & Moe --- #357
# Farmer Weathersky --- Asbjørnsen & Moe --- #365
# The Tortoise and the Eagle --- Aesop --- #501
# The Farmer and the Stork --- Aesop --- #522
# The Eagle and the Arrow --- Aesop --- #570
# The Peasant and the Eagle --- Aesop --- #599
# The Oaks and Jupiter --- Aesop --- #604
# The Jackdaw and the Doves --- Aesop --- #628
# The Horse and the Stag --- Aesop --- #629
# The Wasps, the Partridges, and the Farmer --- Aesop --- #643
# The Ant and the Dove --- Aesop --- #673
# The Ass and the Charger --- Aesop --- #686
# The Steward of Skalholt. --- Jón Árnason --- #708
# The Kite and the Doves --- Phaedrus --- #735
# The Horse and Boar --- Phaedrus --- #770
# The Eagle and the Jackdaw --- Aesop --- #848
#
# #### 10 ###
#
# Cat and mouse in partnership --- Jacob & Wilhelm Grimm --- #0
# The Mouse, the Bird, and the Sausage --- Jacob & Wilhelm Grimm --- #15
# Soup from a sausage skewer --- H.C. Andersen --- #226
# Daughter and Stepdaughter --- Alexander Afanasyev --- #468
# The Bat and the Weasels  --- Aesop --- #509
# The Lion and the Mouse --- Aesop --- #511
# The Lion, the Mouse, and the Fox --- Aesop --- #539
# The Mouse, the Frog, and the Hawk --- Aesop --- #561
# The Mice and the Weasels --- Aesop --- #577
# The Cat and Venus --- Aesop --- #669
# The Ant and the Snow --- Adolfo Coelho --- #703
# The Man and the Weasel --- Phaedrus --- #728
# Mustela et Mus --- Phaedrus --- #764
# The Mountain in Labor --- Phaedrus --- #767
# The Battle of the Mice and Weasels --- Phaedrus --- #772
# Mustela et Mus --- Phaedrus --- #785
# The League of Rats --- Jean de La Fontaine --- #842
# The Lion and the Mouse --- nan --- #853
# The City Mouse and the Country Mouse --- Aesop --- #893
# The Mouse --- Francesc Maspons Labrós --- #903
#
# #### 11 ###
#
# The Bremen town musicians --- Jacob & Wilhelm Grimm --- #19
# The crumbs on the table --- Jacob & Wilhelm Grimm --- #137
# The Dog and the Shadow --- Aesop --- #518
# The Fawn and His Mother --- Aesop --- #523
# The Mischievous Dog --- Aesop --- #541
# The Man Bitten by a Dog --- Aesop --- #562
# The Two Dogs --- Aesop --- #567
# The Brazier and His Dog --- Aesop --- #584
# The Dog, the Cock, and the Fox --- Aesop --- #634
# The Dogs and the Hides --- Aesop --- #660
# The Dog and the Oyster --- Aesop --- #672
# The Dog and the Cook --- Aesop --- #677
# The Hungry Dogs --- Phaedrus --- #726
# The Faithful House-dog --- Phaedrus --- #729
# The Dog and the Crocodile --- Phaedrus --- #731
# The Dog, Treasure, and Vulture --- Phaedrus --- #733
# The Dog in the River --- Phaedrus --- #736
# The Man and the Dog --- Phaedrus --- #742
# The Dog and the Lamb --- Phaedrus --- #748
# The Dog and the Wolf --- Phaedrus --- #757
# The Old Dog and the Huntsman --- Phaedrus --- #776
# The Man and the Dog --- Phaedrus --- #783
# Elephant And Pug --- Ivan Krylov --- #791
# The Dog Who Carried his Master's Dinner --- Jean de La Fontaine --- #818
# Education --- Jean de La Fontaine --- #821
# The Dog and the Cheese --- Marie de France --- #846
#
# #### 12 ###
#
# Trusty John --- Jacob & Wilhelm Grimm --- #2
# Rapunzel --- Jacob & Wilhelm Grimm --- #6
# The white snake --- Jacob & Wilhelm Grimm --- #9
# The riddle --- Jacob & Wilhelm Grimm --- #14
# The singing bone --- Jacob & Wilhelm Grimm --- #20
# The devil with the three golden hairs --- Jacob & Wilhelm Grimm --- #21
# Sleeping Beauty (Little Briar Rose) --- Jacob & Wilhelm Grimm --- #38
# The queen bee --- Jacob & Wilhelm Grimm --- #49
# The three children of fortune --- Jacob & Wilhelm Grimm --- #56
# The goose girl --- Jacob & Wilhelm Grimm --- #72
# Old Rinkrank --- Jacob & Wilhelm Grimm --- #142
# The princess and the pea --- H.C. Andersen --- #151
# The travelling companion --- H.C. Andersen --- #155
# The swineherd --- H.C. Andersen --- #168
# The jumper --- H.C. Andersen --- #179
# The flea and the professor --- H.C. Andersen --- #285
# Evening, Midnight and Dawn --- Alexander Afanasyev --- #302
# The Fire-Bird and Princess Vassilissa --- Alexander Afanasyev --- #307
# True and Untrue --- Asbjørnsen & Moe --- #325
# Boots Who Made the Princess Say, That's A Story --- Asbjørnsen & Moe --- #331
# The Twelve Wild Ducks --- Asbjørnsen & Moe --- #332
# Tatterhood --- Asbjørnsen & Moe --- #372
# The Big Bird Dan --- Asbjørnsen & Moe --- #379
# The Green Knight --- Asbjørnsen & Moe --- #383
# The Golden Bird --- Asbjørnsen & Moe --- #384
# King Valemon, The White Bear --- Asbjørnsen & Moe --- #385
# The Three Lemons --- Asbjørnsen & Moe --- #394
# The Priest And The Clerk --- Asbjørnsen & Moe --- #396
# The Charcoal-burner --- Asbjørnsen & Moe --- #397
# Rumble-Mumble Goose-Egg --- Asbjørnsen & Moe --- #414
# The Sleeping Beauty in the Wood --- Charles Perrault --- #420
# Cenerentola --- Giambattista Basile --- #422
# The Master Cat; or, Puss in Boots --- Charles Perrault --- #425
# Cinderella; or, The Little Glass Slipper --- Charles Perrault --- #427
# Ricky of the Tuft --- Charles Perrault --- #428
# Sun, Moon, and Talia --- Giambattista Basile --- #430
# Peruonto --- Giambattista Basile --- #433
# The Merchant --- Giambattista Basile --- #435
# Goat-Face --- Giambattista Basile --- #436
# The Enchanted Doe --- Giambattista Basile --- #437
# Pippo --- Giambattista Basile --- #441
# Canntella --- Giambattista Basile --- #444
# The Stone in the Cock's Head --- Giambattista Basile --- #447
# The Three Enchanted Princes --- Giambattista Basile --- #448
# The Dragon --- Giambattista Basile --- #449
# The Two Cakes --- Giambattista Basile --- #450
# The Raven --- Giambattista Basile --- #451
# Pintosmalto --- Giambattista Basile --- #453
# Baldak Borisevich --- Alexander Afanasyev --- #460
# The Magic Ring --- Alexander Afanasyev --- #465
# The Golden Horseshoe the Golden Feather and the Golden Hair --- Dobšinský Pavol --- #470
# Godmother Death and the Doctor Who Worked Miracles --- Dobšinský Pavol --- #471
# The Bird of Truth --- Fernán Caballero --- #473
# The Princess Bella-Flor --- Fernán Caballero --- #474
# The Blue Bird --- Madame d'Aulnoy --- #478
# Tale of the dead princessand the seven knights --- Aleksandr Pushkin --- #479
# The Fire-blower --- Francesc Maspons Labrós --- #488
# Tartaro and Petit Perroquet --- Wentworth Webster --- #494
# Faithful John --- Jacob & Wilhelm Grimm --- #695
# The dancing water, the singing apple, and the speaking bird --- Giuseppe Pitrè --- #698
# The Cistern --- Giuseppe Pitrè --- #699
# Water and Salt --- Giuseppe Pitrè --- #702
# Litill, Tritill, the Birds and the Peasant Lad --- Jón Árnason --- #705
# Geirlug the King's Daughter --- Jón Árnason --- #707
# The Witch in the Stone Boat --- Jón Árnason --- #792
# Bash-Chalek; Or, True Steel --- Vuk Stefanović Karadžić --- #796
# The Yellow Dwarf --- Madame d'Aulnoy --- #869
# Felicia and the Pot of Pinks --- Madame d'Aulnoy --- #873
# The Wonderful Sheep --- Madame d'Aulnoy --- #874
# The Story of Pretty Goldilocks --- Madame d'Aulnoy --- #875
# The Goose-Girl --- Jacob & Wilhelm Grimm --- #877
# The Princess on the Glass Hill --- Asbjørnsen & Moe --- #879
# Princess Rosette --- Madame d'Aulnoy --- #880
# The Knights of Fish --- Fernán Caballero --- #882
# The Little Good Mouse --- Madame d'Aulnoy --- #883
# The Blue Lily --- Fernán Caballero --- #904
#
# #### 13 ###
#
# Right and Wrong --- Alexander Afanasyev --- #299
# Prince Ivan and Princess Martha --- Alexander Afanasyev --- #300
# The Three Kingdoms --- Alexander Afanasyev --- #301
# Marya Morevna --- Alexander Afanasyev --- #304
# King Ivan and Bely, the Warrior of the Plains --- Alexander Afanasyev --- #305
# The King of the Sea and Vassilissa the Wise --- Alexander Afanasyev --- #310
# The Prophetic Dream --- Alexander Afanasyev --- #313
# Tsarevich Ivan and Grey Wolf --- Alexander Afanasyev --- #324
# The Princess Frog --- Alexander Afanasyev --- #467
#
# #### 14 ###
#
# The twelve brothers --- Jacob & Wilhelm Grimm --- #5
# The three snake-leaves --- Jacob & Wilhelm Grimm --- #8
# The six swans --- Jacob & Wilhelm Grimm --- #37
# King Thrushbeard --- Jacob & Wilhelm Grimm --- #40
# The two brothers --- Jacob & Wilhelm Grimm --- #47
# The three feathers --- Jacob & Wilhelm Grimm --- #50
# All-kinds-of-fur --- Jacob & Wilhelm Grimm --- #52
# The twelve huntsmen --- Jacob & Wilhelm Grimm --- #53
# Six soldiers of fortune --- Jacob & Wilhelm Grimm --- #57
# The gnome --- Jacob & Wilhelm Grimm --- #74
# The three little birds --- Jacob & Wilhelm Grimm --- #78
# The water of life --- Jacob & Wilhelm Grimm --- #79
# Hans my Hedgehog --- Jacob & Wilhelm Grimm --- #85
# The skilful huntsman --- Jacob & Wilhelm Grimm --- #86
# Donkey cabbages --- Jacob & Wilhelm Grimm --- #89
# The iron stove --- Jacob & Wilhelm Grimm --- #94
# The four skilful brothers --- Jacob & Wilhelm Grimm --- #95
# The white bride and the black one --- Jacob & Wilhelm Grimm --- #101
# Iron John --- Jacob & Wilhelm Grimm --- #102
# The donkey --- Jacob & Wilhelm Grimm --- #108
# The Riddle --- Alexander Afanasyev --- #316
# Peik --- Asbjørnsen & Moe --- #413
# Three Coppers --- Dobšinský Pavol --- #472
# Anansi in hunger --- unknown author --- #484
# The Stepmother --- Giuseppe Pitrè --- #696
# The Cobbler Turned Doctor --- Phaedrus --- #720
# The Sapient Ass --- Phaedrus --- #721
# The Lion, the Monkey, and the Two Asses --- Jean de La Fontaine --- #832
#
# #### 15 ###
#
# Brides on their trial --- Jacob & Wilhelm Grimm --- #113
# Choosing a Bride --- Jacob & Wilhelm Grimm --- #459
# The Crow and the Fox --- Jean de La Fontaine --- #481
# The Fox and the Crow --- Aesop --- #491
# The Swallow and the Crow --- Aesop --- #525
# The Crow and the Raven --- Aesop --- #612
# The Crow and Mercury --- Aesop --- #644
# The Dove and the Crow --- Aesop --- #653
# The Crow and the Serpent --- Aesop --- #668
# The Fox and the Crow --- Phaedrus --- #719
# Juno and the Peacock --- Phaedrus --- #751
# The Fox and the Crow --- Babrius --- #797
# The Crow and the Peacock --- unknown author --- #854
# The fox and the crow --- Aesop --- #858
#
# #### 16 ###
#
# The fox and the horse --- Jacob & Wilhelm Grimm --- #98
# The Ass, the Fox, and the Lion --- Aesop --- #526
# The Lioness --- Aesop --- #535
# The Wild Ass and the Lion --- Aesop --- #569
# The Lion and the Dolphin --- Aesop --- #572
# The Ass, the Cock, and the Lion --- Aesop --- #576
# The Lion in a Farmyard --- Aesop --- #589
# The Lion, the Bear, and the Fox --- Aesop --- #595
# The Doe and the Lion --- Aesop --- #596
# The Lion, the Fox, and the Ass --- Aesop --- #609
# The Gnat and the Lion --- Aesop --- #626
# The Lion, the Wolf, and the Fox --- Aesop --- #648
# The Wolf and the Lion --- Aesop --- #649
# The Lion, Jupiter, and the Elephant --- Aesop --- #680
# The Viper and the File --- Aesop --- #684
# The King's Son and the Painted Lion --- Aesop --- #692
# The Ass and the Lion Hunting --- Phaedrus --- #717
# The Old Lion --- Phaedrus --- #727
# The Judicious Lion --- Phaedrus --- #740
# The Horoscope --- Jean de La Fontaine --- #820
# The Lion and the Mouse --- unknown author --- #852
# The Lion and the Shepherd --- George Fyler Townsend --- #857
# The Lion, the Panther, the Tazourit, and the Jackal --- unknown author --- #859
# Lion Share --- Abdulkhaliq Shikh-Osman --- #898
# The Cow, the Goat, the Sheep, and the Lion --- Phaedrus --- #899
#
# #### 17 ###
#
# The great sea serpent --- H.C. Andersen --- #279
# Golden Fish --- Alexander Afanasyev --- #463
# The Knights of the Fish --- Fernán Caballero --- #475
# Tale of the fisherman and the little fish --- Aleksandr Pushkin --- #480
# The Fisherman Piping --- Aesop --- #516
# The Fisherman and His Nets --- Aesop --- #566
# The Fisherman and the Little Fish --- Aesop --- #587
# The Monkey and the Fishermen --- Aesop --- #592
# The Seagull and the Kite --- Aesop --- #597
# The Fishermen --- Aesop --- #638
# The Shipwrecked Man and the Sea --- Aesop --- #683
#
# #### 18 ###
#
# Straw, coal, and bean --- Jacob & Wilhelm Grimm --- #10
# The Dog and the Sparrow --- Jacob & Wilhelm Grimm --- #45
# Clever Grethel --- Jacob & Wilhelm Grimm --- #62
# The seven Swabians --- Jacob & Wilhelm Grimm --- #88
# The tale of Cockaigne --- Jacob & Wilhelm Grimm --- #116
# The moon --- Jacob & Wilhelm Grimm --- #127
# The nail --- Jacob & Wilhelm Grimm --- #132
# The golden key --- Jacob & Wilhelm Grimm --- #146
# Two maidens --- H.C. Andersen --- #214
# The rags --- H.C. Andersen --- #267
# The candles --- H.C. Andersen --- #277
# The gate key --- H.C. Andersen --- #282
# The Tallow Candle --- H.C. Andersen --- #286
# Emelya and the Pike --- Alexander Afanasyev --- #306
# The Horse, the Table-Cloth and the Horn --- Alexander Afanasyev --- #308
# The Mountain of Gold --- Alexander Afanasyev --- #314
# Ivan the Fool --- Alexander Afanasyev --- #319
# Good But Bad --- Alexander Afanasyev --- #320
# One's Own Children Are Always Prettiest --- Asbjørnsen & Moe --- #349
# The Cock, the Cuckoo, and the Blackcock --- Asbjørnsen & Moe --- #353
# The Three Billy-Goats Gruff --- Asbjørnsen & Moe --- #361
# The Cock and Hen a-Nutting --- Asbjørnsen & Moe --- #378
# The Box With Something Pretty In It --- Asbjørnsen & Moe --- #391
# The Skipper And Old Nick --- Asbjørnsen & Moe --- #412
# The Frog and Ox --- Jean de La Fontaine --- #482
# The Cat and the Fox --- Jean de La Fontaine --- #490
# The Two Mules --- Jean de La Fontaine --- #492
# The Baker's Apprentice --- Giuseppe Pitrè --- #502
# The Boy Bathing --- Aesop --- #505
# The Ass and the Grasshopper  --- Aesop --- #510
# The Charcoal-Burner and the Fuller --- Aesop --- #512
# The Flies and the Honey-Pot --- Aesop --- #527
# The Bear and the Two Travelers --- Aesop --- #529
# The Oxen and the Axle-Trees --- Aesop --- #530
# The Thirsty Pigeon --- Aesop --- #531
# The Miser --- Aesop --- #532
# The Horse and Groom --- Aesop --- #533
# The Ass and the Lapdog --- Aesop --- #534
# The Piglet, the Sheep, and the Goat --- Aesop --- #536
# The Ass and the Mule --- Aesop --- #537
# The Salt Merchant and His Ass --- Aesop --- #538
# The Astronomer --- Aesop --- #544
# The Charger and the Miller --- Aesop --- #547
# The Belly and the Members --- Aesop --- #549
# The Vine and the Goat --- Aesop --- #550
# The Heifer and the Ox --- Aesop --- #556
# The Fir-Tree and the Bramble --- Aesop --- #560
# The Two Pots --- Aesop --- #563
# The Aethiop --- Aesop --- #565
# The Widow and the Sheep --- Aesop --- #568
# The Lion and the Boar --- Aesop --- #573
# The One-Eyed Doe --- Aesop --- #574
# The Shepherd and the Sea --- Aesop --- #575
# The Master and His Dogs --- Aesop --- #579
# The Ass Carrying the Image --- Aesop --- #580
# The Two Travelers and the Axe --- Aesop --- #581
# The Bee and Jupiter --- Aesop --- #582
# The Seaside Travelers --- Aesop --- #583
# The Ass and His Masters --- Aesop --- #585
# The Oak and the Reeds --- Aesop --- #586
# Mercury and the Sculptor --- Aesop --- #590
# The Two Frogs --- Aesop --- #594
# The Traveler and Fortune --- Aesop --- #605
# The Bald Knight --- Aesop --- #606
# The Lamp --- Aesop --- #608
# The Ass and the Frogs --- Aesop --- #611
# The Camel --- Aesop --- #618
# The Mule --- Aesop --- #622
# The Hart and the Vine --- Aesop --- #623
# The Two Frogs --- Aesop --- #624
# The Walnut-Tree --- Aesop --- #625
# The Prophet --- Aesop --- #631
# The Goat and the Ass --- Aesop --- #637
# The Fowler and the Viper --- Aesop --- #639
# The Geese and the Cranes --- Aesop --- #640
# The North Wind and the Sun --- Aesop --- #645
# The Flea and the Ox --- Aesop --- #652
# Mercury and the Workmen --- Aesop --- #654
# The Two Bags --- Aesop --- #657
# The Shepherd and the Sheep --- Aesop --- #661
# The Monkey and the Camel --- Aesop --- #662
# The Peasant and the Apple-Tree --- Aesop --- #663
# The Manslayer --- Aesop --- #666
# The Partridge and the Fowler --- Aesop --- #674
# The Flea and the Man --- Aesop --- #675
# The Thieves and the Cock --- Aesop --- #676
# The Travelers and the Plane-Tree --- Aesop --- #678
# The Ass and His Driver --- Aesop --- #687
# The Thrush and the Fowler --- Aesop --- #688
# The Frogs' Complaint Against the Sun --- Aesop --- #693
# The Mirror of Truth --- Jean-Pierre Claris de Florian --- #709
# The Two Travellers --- Jean-Pierre Claris de Florian --- #710
# The Inquisitive Cat --- Jean-Pierre Claris de Florian --- #711
# The Two Gardeners --- Jean-Pierre Claris de Florian --- #713
# The Frog and the Rat --- Jean de La Fontaine --- #714
# The Stag at the Fountain --- Phaedrus --- #718
# The Bitch and Her Puppies --- Phaedrus --- #724
# The Frogs Desiring a King --- Phaedrus --- #725
# The Proud Frog --- Phaedrus --- #730
# The Frogs and Sun --- Phaedrus --- #737
# The Bald-pate Dupe --- Phaedrus --- #741
# The Old Woman and Empty Cask --- Phaedrus --- #743
# The Bees and the Drone --- Phaedrus --- #746
# The Owl and the Grasshopper --- Phaedrus --- #749
# The Trees Protected --- Phaedrus --- #750
# Esop and the Importunate Fellow --- Phaedrus --- #752
# The Panther and Shepherds --- Phaedrus --- #753
# Esop and the Insolent Fellow --- Phaedrus --- #755
# The Ass and Priests of Cybele --- Phaedrus --- #759
# The Two Bags --- Phaedrus --- #760
# The Escape of Simonides --- Phaedrus --- #768
# The Viper and the File --- Phaedrus --- #773
# Demetrius and Menander --- Phaedrus --- #775
# The Stag and the Oxen --- Phaedrus --- #782
# The Ant --- Ivan Krylov --- #788
# A Hog under an Oak --- Ivan Krylov --- #800
# The Grasshopper and the Ant --- Jean de La Fontaine --- #802
# The Rat and the Elephant --- Jean de La Fontaine --- #803
# The Man and his Image --- Jean de La Fontaine --- #806
# The Unhappily Married Man --- Jean de La Fontaine --- #808
# The Rat Retired From the World --- Jean de La Fontaine --- #809
# The Maiden --- Jean de La Fontaine --- #810
# The Wishes --- Jean de La Fontaine --- #811
# The Dairy-woman and the Pail of Milk --- Jean de La Fontaine --- #812
# The Priest and the Corpse --- Jean de La Fontaine --- #813
# The Man Who Ran After Fortune and The Man Who Waited For her In his Bed --- Jean de La Fontaine --- #814
# The Fortune-tellers --- Jean de La Fontaine --- #815
# The Power of Fable --- Jean de La Fontaine --- #817
# Thyrsis and Amaranth --- Jean de La Fontaine --- #819
# The Acorn and the Pumpkin --- Jean de La Fontaine --- #823
# The Schoolboy, the Pedant, and the Owner of a Garden --- Jean de La Fontaine --- #824
# The Sculptor and the Statue of Jupiter --- Jean de La Fontaine --- #825
# The Oyster and the Pleaders --- Jean de La Fontaine --- #826
# The Monkey and the Cat --- Jean de La Fontaine --- #827
# The Two Rats, the Fox, and the Egg --- Jean de La Fontaine --- #828
# The Dog With his Ears Cropped --- Jean de La Fontaine --- #829
# The Rabbits --- Jean de La Fontaine --- #830
# Love and Folly --- Jean de La Fontaine --- #836
# The Forest and the Woodcutter --- Jean de La Fontaine --- #837
# The Ape --- Jean de La Fontaine --- #839
# The Scythian Philosopher --- Jean de La Fontaine --- #840
# The Elephant and Jupiter's Ape --- Jean de La Fontaine --- #841
# The Arbiter, the Hospitaller, and the Hermit --- Jean de La Fontaine --- #843
# The Rooster and the Gem --- Marie de France --- #847
# The Fly and the Bee --- Ivan Krylov --- #849
# The Hawk and the Nightingale --- Aesop --- #860
# The Turtoise and the Geese --- Bidpai --- #862
# The Appointment in Samarra --- William Somerset Maugham --- #863
# When Death Came to Baghdad --- Fudail Ibn Ayad --- #864
# The Linguist and the Dervish --- nan --- #866
# The Altercation between Spring and Summer  --- E. A. Ruskin --- #886
# Copa Nanzi and the Cow --- unknown author --- #889
# The Robbers and the Farm Animals --- Otto Sutermeister --- #891
# The Town Rat and the Country Rat --- Jean de La Fontaine --- #894
# The Ass and the Flute --- Tomás de Iriarte --- #896
# The Two Flies and the Bee --- Ivan Krylov --- #897
#
# #### 19 ###
#
# Herr Korbes --- Jacob & Wilhelm Grimm --- #31
# The death of the little hen --- Jacob & Wilhelm Grimm --- #63
# The ugly duckling --- H.C. Andersen --- #173
# There is no doubt about it --- H.C. Andersen --- #206
# The farm-yard cock and the weather-cock --- H.C. Andersen --- #237
# In the duck yard --- H.C. Andersen --- #244
# The Cock and Hen --- Asbjørnsen & Moe --- #339
# The Cock and Hen That Went to the Dovrefell --- Asbjørnsen & Moe --- #373
# The Widow and Her Little Maidens --- Aesop --- #551
# The Hen and the Golden Eggs --- Aesop --- #610
# The Woman and Her Hen --- Aesop --- #614
# The Hen and the Swallow --- Aesop --- #667
#
# #### 20 ###
#
# The Elves --- Jacob & Wilhelm Grimm --- #29
# The robber bridegroom --- Jacob & Wilhelm Grimm --- #30
# The old beggar-woman --- Jacob & Wilhelm Grimm --- #112
# The goose-girl at the well --- Jacob & Wilhelm Grimm --- #129
# The Saucy Boy --- H.C. Andersen --- #154
# The goloshes of fortune --- H.C. Andersen --- #158
# The flying trunk --- H.C. Andersen --- #164
# Top and Ball --- H.C. Andersen --- #172
# The elderbush --- H.C. Andersen --- #176
# The elfin hill --- H.C. Andersen --- #177
# The red shoes --- H.C. Andersen --- #178
# The shepherdess and the sweep --- H.C. Andersen --- #180
# Holger Danske --- H.C. Andersen --- #181
# The darning-needle --- H.C. Andersen --- #184
# The little match-seller --- H.C. Andersen --- #185
# The old street lamp --- H.C. Andersen --- #188
# Little Tuk --- H.C. Andersen --- #190
# The old house --- H.C. Andersen --- #192
# The happy family --- H.C. Andersen --- #194
# The shirt-collar --- H.C. Andersen --- #196
# In a thousand years --- H.C. Andersen --- #201
# The old grave-stone --- H.C. Andersen --- #203
# Heartache --- H.C. Andersen --- #208
# Everything in its proper place --- H.C. Andersen --- #209
# The goblin and the huckster --- H.C. Andersen --- #210
# Under the willow tree --- H.C. Andersen --- #211
# The moneybox --- H.C. Andersen --- #217
# Ib and little Christina --- H.C. Andersen --- #220
# A string of pearls --- H.C. Andersen --- #223
# The bottle neck --- H.C. Andersen --- #225
# The old bachelor's nightcap --- H.C. Andersen --- #227
# Something --- H.C. Andersen --- #228
# The stone of the wise man --- H.C. Andersen --- #233
# Ole the tower-keeper --- H.C. Andersen --- #236
# Twelve by the mail --- H.C. Andersen --- #240
# What the old man does is always right --- H.C. Andersen --- #242
# The old church bell --- H.C. Andersen --- #246
# The silver shilling --- H.C. Andersen --- #247
# The metal pig --- H.C. Andersen --- #248
# A story --- H.C. Andersen --- #251
# The teapot --- H.C. Andersen --- #254
# The windmill --- H.C. Andersen --- #256
# Kept secret but not forgotten --- H.C. Andersen --- #257
# Aunty --- H.C. Andersen --- #258
# The goblin and the woman --- H.C. Andersen --- #262
# The puppet-show man --- H.C. Andersen --- #265
# The days of the week --- H.C. Andersen --- #266
# The comet --- H.C. Andersen --- #268
# Chicken Grethe's family --- H.C. Andersen --- #270
# What one can invent --- H.C. Andersen --- #272
# Luck may lie in a pin --- H.C. Andersen --- #273
# Great-Grandfather --- H.C. Andersen --- #275
# The most incredible thing --- H.C. Andersen --- #276
# What old Johanne told --- H.C. Andersen --- #281
# Aunty Toothache --- H.C. Andersen --- #284
# The Greedy Old Woman --- Alexander Afanasyev --- #296
# The Fortune-Teller --- Alexander Afanasyev --- #318
# Vasilisa the Beautiful --- Alexander Afanasyev --- #323
# The Old Woman and the Physician --- Aesop --- #546
# The Piper and the Puca --- Douglas Hyde --- #789
# The old man, the boy and the donkey --- unknown author --- #861
#
# #### 21 ###
#
# The thief and his master --- Jacob & Wilhelm Grimm --- #54
# The three black princesses --- Jacob & Wilhelm Grimm --- #103
# Simeli mountain --- Jacob & Wilhelm Grimm --- #106
# A Cunning Trade --- Alexander Afanasyev --- #315
# The Farmer and His Sons --- Aesop --- #554
# The Wasp and the Snake --- Aesop --- #619
# The Two Men Who Were Enemies --- Aesop --- #646
# The Carp and her Young --- Jean-Pierre Claris de Florian --- #712
# Hercules and Plutus --- Phaedrus --- #762
# The Shipwreck of Simonides --- Phaedrus --- #766
# The Black Monkey and the Turtoise --- E. A. Ruskin --- #888
#
# #### 22 ###
#
# The blue light --- Jacob & Wilhelm Grimm --- #87
# The devil and his grandmother --- Jacob & Wilhelm Grimm --- #92
# The shoes that were danced to pieces --- Jacob & Wilhelm Grimm --- #99
# The grave-mound --- Jacob & Wilhelm Grimm --- #141
# The boots of buffalo-leather --- Jacob & Wilhelm Grimm --- #145
# The tinder-box --- H.C. Andersen --- #149
# The brave tin soldier --- H.C. Andersen --- #160
# Go I Know Not Where, Bring I Know Not What --- Alexander Afanasyev --- #309
# Elena the Wise --- Alexander Afanasyev --- #312
# The Horse and His Rider --- Aesop --- #548
# The Trumpeter Taken Prisoner --- Aesop --- #651
#
# #### 23 ###
#
# The Wolf and the Seven Young Kids --- Jacob & Wilhelm Grimm --- #1
# Little Red Riding Hood --- Jacob & Wilhelm Grimm --- #18
# Old Sultan --- Jacob & Wilhelm Grimm --- #36
# The Wolf and the Goat --- Alexander Afanasyev --- #291
# Little Red Riding Hood --- Charles Perrault --- #423
# The Ass and the Wolf --- Wentworth Webster --- #495
# The Wolf and the Lamb --- Jean de La Fontaine --- #504
# The Ass and the Wolf --- Aesop --- #506
# The Wolf and the Lamb --- Aesop --- #508
# The Wolf and the Crane --- Aesop --- #515
# The Wolves and the Sheep --- Aesop --- #545
# The Shepherd and the Wolf --- Aesop --- #552
# The Wolf and the Sheep --- Aesop --- #564
# The Wolf and the Housedog --- Aesop --- #578
# The Shepherd and the Dog --- Aesop --- #607
# The Wolves and the Sheepdogs --- Aesop --- #616
# The Kid and the Wolf --- Aesop --- #630
# The Wolf and the Shepherd --- Aesop --- #632
# The Wolf and the Goat --- Aesop --- #635
# The Blind Man and the Whelp --- Aesop --- #641
# The Wolf and the Horse --- Aesop --- #642
# The Mother and the Wolf --- Aesop --- #664
# The Wolf and the Lion --- Aesop --- #671
# The Lamb and the Wolf --- Aesop --- #681
# The Shepherd's Boy and the Wolf --- Aesop --- #690
# The Wolf and the Lamb --- Phaedrus --- #715
# The Sheep, the Stag, and the Wolf --- Phaedrus --- #722
# The Sheep, the Dog, and the Wolf --- Phaedrus --- #723
# The Wolf and Crane --- Phaedrus --- #739
# The Animals Sick of the Plague --- Jean de La Fontaine --- #807
# The Companions of Ulysses --- Jean de La Fontaine --- #834
# The Wolf and the Fox --- Jean de La Fontaine --- #835
# The Lion, Wolf, and Fox --- Jean de La Fontaine --- #890
#
# #### 24 ###
#
# The Animals' Winter Home --- Alexander Afanasyev --- #293
# Two bulls and the frog --- Jean de La Fontaine --- #483
# The Herdsman and the Lost Bull --- Aesop --- #520
# The Bull and the Goat --- Aesop --- #601
# The Lion and the Bull --- Aesop --- #636
# The Gnat and the Bull --- Aesop --- #659
# The Camel and Jupiter --- Aesop --- #685
# The Man and the Adder --- Phaedrus --- #765
# The Bull and the Calf --- Phaedrus --- #781
# The Frogs and the Fighting Bulls --- Phaedrus --- #798
# The Man and the Adder --- Phaedrus --- #845
# The Lion and the Three Bulls --- Aesop --- #856
# The Bull, the Tup, the Cock, and the Steg --- Alice Ecleston --- #892
#
# #### 25 ###
#
# Shortshanks --- Asbjørnsen & Moe --- #344
# Little Thumb --- Charles Perrault --- #429
# The Seven Doves --- Giambattista Basile --- #432
# The Flea --- Giambattista Basile --- #434
# Parsley --- Giambattista Basile --- #438
# The Three Sisters --- Giambattista Basile --- #439
# Corvetto --- Giambattista Basile --- #445
# The Golden Root --- Giambattista Basile --- #454
# Don Firriulieddu --- Giuseppe Pitrè --- #503
# The King of Love --- Giuseppe Pitrè --- #697
# Snow-White-Fire-Red --- Giuseppe Pitrè --- #700
# Thirteenth --- Giuseppe Pitrè --- #701
#
# #### 26 ###
#
# The good bargain --- Jacob & Wilhelm Grimm --- #3
# The Valiant Little Tailor --- Jacob & Wilhelm Grimm --- #12
# The Louse and the Flea --- Jacob & Wilhelm Grimm --- #22
# The girl without hands --- Jacob & Wilhelm Grimm --- #23
# The three languages --- Jacob & Wilhelm Grimm --- #25
# The Wishing-Table, the Gold-Ass, and the Cudgel in the Sack --- Jacob & Wilhelm Grimm --- #28
# Frau Trude --- Jacob & Wilhelm Grimm --- #33
# Bird-foundling --- Jacob & Wilhelm Grimm --- #39
# The knapsack, the hat, and the horn --- Jacob & Wilhelm Grimm --- #41
# The little peasant --- Jacob & Wilhelm Grimm --- #48
# The singing, springing lark --- Jacob & Wilhelm Grimm --- #71
# The young giant --- Jacob & Wilhelm Grimm --- #73
# The king of the golden mountain --- Jacob & Wilhelm Grimm --- #75
# The raven --- Jacob & Wilhelm Grimm --- #76
# Bearskin --- Jacob & Wilhelm Grimm --- #82
# The two travellers --- Jacob & Wilhelm Grimm --- #84
# The old woman in the wood --- Jacob & Wilhelm Grimm --- #90
# Ferdinand the faithful --- Jacob & Wilhelm Grimm --- #93
# One-eye, two-eyes, and three-eyes --- Jacob & Wilhelm Grimm --- #96
# The six servants --- Jacob & Wilhelm Grimm --- #100
# Domestic servants --- Jacob & Wilhelm Grimm --- #105
# Going a-travelling --- Jacob & Wilhelm Grimm --- #107
# The turnip --- Jacob & Wilhelm Grimm --- #110
# The sparrow and his four children --- Jacob & Wilhelm Grimm --- #115
# The glass coffin --- Jacob & Wilhelm Grimm --- #119
# Lazy Harry --- Jacob & Wilhelm Grimm --- #120
# Lean Lisa --- Jacob & Wilhelm Grimm --- #124
# The duration of life --- Jacob & Wilhelm Grimm --- #128
# The nix of the mill-pond --- Jacob & Wilhelm Grimm --- #130
# The giant and the tailor --- Jacob & Wilhelm Grimm --- #131
# The true bride --- Jacob & Wilhelm Grimm --- #134
# The peasant and the devil --- Jacob & Wilhelm Grimm --- #136
# The sea-hare --- Jacob & Wilhelm Grimm --- #138
# The master-thief --- Jacob & Wilhelm Grimm --- #139
# The drummer --- Jacob & Wilhelm Grimm --- #140
# The crystal ball --- Jacob & Wilhelm Grimm --- #143
# Maid Maleen --- Jacob & Wilhelm Grimm --- #144
# Poverty and humility lead to heaven --- Jacob & Wilhelm Grimm --- #147
# The three green twigs --- Jacob & Wilhelm Grimm --- #148
# The Sevens Bits of Bacon-Rind --- Giambattista Basile --- #469
# The Frog-King, or Iron Henry --- Jacob & Wilhelm Grimm --- #498
# Our Lady's Child --- Jacob & Wilhelm Grimm --- #499
# The Story of the Youth who Went Forth to Learn What Fear Was --- Jacob & Wilhelm Grimm --- #500
# Truth and the Traveler --- Aesop --- #665
# The Cock and the Pearl --- Phaedrus --- #745
# Esop Playing --- Phaedrus --- #747
# The Bald Man and the Fly --- Phaedrus --- #777
# Maol a chliobain --- Hector MacLean --- #790
# Asphurtzela --- Vladimir Agniashvili --- #794
#
# #### 27 ###
#
# The elf of the rose --- H.C. Andersen --- #162
# Grandmother --- H.C. Andersen --- #183
# The loveliest rose in the world --- H.C. Andersen --- #200
# The snail and the rosebush --- H.C. Andersen --- #245
# A rose from Homer's grave --- H.C. Andersen --- #250
# The little green ones --- H.C. Andersen --- #261
# Which was the happiest? --- H.C. Andersen --- #264
# The Rose and the Amaranth --- Aesop --- #689
#
# #### 28 ###
#
# The fisherman and his wife --- Jacob & Wilhelm Grimm --- #11
# The godfather --- Jacob & Wilhelm Grimm --- #32
# Godfather Death --- Jacob & Wilhelm Grimm --- #34
# Rumpelstiltskin --- Jacob & Wilhelm Grimm --- #42
# Frederick and Catherine --- Jacob & Wilhelm Grimm --- #46
# The golden goose --- Jacob & Wilhelm Grimm --- #51
# The gold-children --- Jacob & Wilhelm Grimm --- #68
# The poor man and the rich man --- Jacob & Wilhelm Grimm --- #70
# Doctor Know-all --- Jacob & Wilhelm Grimm --- #80
# The spirit in the glass bottle --- Jacob & Wilhelm Grimm --- #81
# The three brothers --- Jacob & Wilhelm Grimm --- #91
# The ungrateful son --- Jacob & Wilhelm Grimm --- #109
# Sharing joy and sorrow --- Jacob & Wilhelm Grimm --- #125
# The owl --- Jacob & Wilhelm Grimm --- #126
# The emperor's new suit --- H.C. Andersen --- #157
# The Nightingale --- H.C. Andersen --- #171
# The shadow --- H.C. Andersen --- #191
# The beetle --- H.C. Andersen --- #241
# The Wise Maid and the Seven Robbers --- Alexander Afanasyev --- #317
# The Miser --- Alexander Afanasyev --- #321
# Why the Sea Is Salt --- Asbjørnsen & Moe --- #326
# The Old Dame and Her Hen --- Asbjørnsen & Moe --- #327
# The Master-Smith --- Asbjørnsen & Moe --- #340
# Buttercup --- Asbjørnsen & Moe --- #342
# Gudbrand on the Hill-side --- Asbjørnsen & Moe --- #345
# Not a Pin to Choose Between Them --- Asbjørnsen & Moe --- #348
# The Master Thief --- Asbjørnsen & Moe --- #359
# The Husband Who Was to Mind the House --- Asbjørnsen & Moe --- #363
# Goody Gainst-the-stream --- Asbjørnsen & Moe --- #389
# The Pancake --- Asbjørnsen & Moe --- #393
# Friends In Life And Death --- Asbjørnsen & Moe --- #395
# The Way Of The World --- Asbjørnsen & Moe --- #398
# Goodman Axehaft --- Asbjørnsen & Moe --- #400
# Silly Men And Cunning Wives --- Asbjørnsen & Moe --- #403
# The Father Of The Family --- Asbjørnsen & Moe --- #404
# The Town-mouse And The Fell-mouse --- Asbjørnsen & Moe --- #409
# The Sheep And The Pig Who Set Up House --- Asbjørnsen & Moe --- #411
# Blue Beard --- Charles Perrault --- #424
# The Months --- Giambattista Basile --- #452
# The Fool and the Birch Tree --- Alexander Afanasyev --- #461
# The Tartaro --- Wentworth Webster --- #493
# The Man and His Two Sweethearts --- Aesop --- #543
# The Father and His Two Daughters --- Aesop --- #553
# The Old Man and Death --- Aesop --- #559
# The Flea and the Wrestler --- Aesop --- #593
# The Image of Mercury and the Carpenter --- Aesop --- #600
# The Monkey and the Dolphin --- Aesop --- #627
# The Man and His Wife --- Aesop --- #633
# The Gamecocks and the Partridge --- Aesop --- #647
# The Man and the Satyr --- Aesop --- #655
# The Ass and His Purchaser --- Aesop --- #656
# The Rich Man and the Tanner --- Aesop --- #682
# The Cottager and his Cat --- Jón Árnason --- #704
# Of Doubt and Credulity --- Phaedrus --- #744
# Esop and the Will --- Phaedrus --- #771
# The Man and the Ass --- Phaedrus --- #778
# A Saying of Socrates --- Phaedrus --- #784
# The Spider and the Turtle --- unknown author --- #850
# The Fiddler in Hell --- Alexander Afanasiev --- #851
# The Man and the Viper --- Aesop --- #855
# Rumpelstiltzkin --- Jacob & Wilhelm Grimm --- #870
# Why the Sea is Salt --- Asbjørnsen & Moe --- #876
# The Friendship of the Thorn and the Mud-Fish  --- E. A. Ruskin --- #887
# The young man and the monitor lizard --- Dorothea Lehmann --- #901
# Cuội and the Moon --- Nguyễn Đổng Chi --- #907
#
# #### 29 ###
#
# Jorinda and Joringel --- Jacob & Wilhelm Grimm --- #55
# A riddling tale --- Jacob & Wilhelm Grimm --- #117
# Little Ida's flowers --- H.C. Andersen --- #152
# Thumbelina --- H.C. Andersen --- #153
# The daisy --- H.C. Andersen --- #159
# The wild swans --- H.C. Andersen --- #161
# The storks --- H.C. Andersen --- #165
# Ole-Luk-Oie, the Dream-God --- H.C. Andersen --- #167
# The buckwheat --- H.C. Andersen --- #169
# The angel --- H.C. Andersen --- #170
# The fir tree --- H.C. Andersen --- #174
# The snow queen --- H.C. Andersen --- #175
# The bell --- H.C. Andersen --- #182
# By the almshouse window --- H.C. Andersen --- #186
# The neighbouring families --- H.C. Andersen --- #189
# The story of a mother --- H.C. Andersen --- #195
# There is a difference --- H.C. Andersen --- #199
# The story of the year --- H.C. Andersen --- #204
# At the uttermost parts of the sea --- H.C. Andersen --- #216
# A leaf from heaven --- H.C. Andersen --- #218
# The bell deep --- H.C. Andersen --- #224
# The last dream of the old oak --- H.C. Andersen --- #229
# The marsh king's daughter --- H.C. Andersen --- #231
# The wind tells about Valdemar Daae and his daughters --- H.C. Andersen --- #234
# The butterfly --- H.C. Andersen --- #239
# The snowman --- H.C. Andersen --- #243
# The Dumb Book --- H.C. Andersen --- #252
# The snowdrop --- H.C. Andersen --- #253
# The toad --- H.C. Andersen --- #259
# Vänö and Glänö --- H.C. Andersen --- #260
# Peiter, Peter, and Peer --- H.C. Andersen --- #263
# Sunshine stories --- H.C. Andersen --- #269
# What happened to the thistle --- H.C. Andersen --- #271
# The gardener and the noble family --- H.C. Andersen --- #280
# The Ants and the Grasshopper --- Aesop --- #517
# The Spendthrift and the Swallow --- Aesop --- #650
# The ant and the Grasshopper --- Babrius --- #799
# Dragonfly and the Ant --- Ivan Krylov --- #801
